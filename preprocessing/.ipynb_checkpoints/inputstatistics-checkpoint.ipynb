# %% [markdown]
# # Input Statistical Analysis for all datasets

# %%
import numpy as np
import pandas as pd
import spacy
import emoji
from collections import Counter

# %%
DATA_DIR = '../data'

# %% [markdown]
# ### Utility Functions

# %%
def remove_emoji(text):
    return emoji.get_emoji_regexp().sub(u'', text)

def slice_dataframe_and_compute_word_frequency(df, slice_cols, slice_vals, text_col, spacy_lang_pkg):
    sliced_df = df.copy()
    for i in range(len(slice_cols)):
        sliced_df = sliced_df[sliced_df[slice_cols[i]] == slice_vals[i]]
    print(f'Found a total of {len(sliced_df)} examples')
    nlp = spacy.load(spacy_lang_pkg)
    text = ' '.join(sliced_df[text_col])
    text = emoji.get_emoji_regexp().sub(r'', text)
    doc = nlp(text)
    words = [token.text for token in doc if not token.is_stop and not token.is_punct and len(token) > 1]
    freqs = Counter(words)
    return freqs

# %% [markdown]
# ### Spanish (Basile et al.)

# %%
df = pd.read_csv(f'{DATA_DIR}/spanish-basile/hateval2019_es_train.csv')

# %%
df.head()
# Out:
#       id                                               text  HS  TR  AG
# 0  20001  Easyjet quiere duplicar el número de mujeres p...   1   0   0
# 1  20002  El gobierno debe crear un control estricto de ...   1   0   0
# 2  20003  Yo veo a mujeres destruidas por acoso laboral ...   0   0   0
# 3  20004  — Yo soy respetuoso con los demás, sólamente l...   0   0   0
# 4  20007  Antonio Caballero y como ser de mal gusto e ig...   0   0   0

# %% [markdown]
# #### 1.1 Word Frequecy for Examples that are Hate Speech

# %%
freqs = slice_dataframe_and_compute_word_frequency(df, ['HS'], [1], 'text', 'es_core_news_sm')
freqs.most_common()[:10]
# Out:
# Found a total of 1857 examples
# [('puta', 418),
#  ('perra', 345),
#  ('zorra', 216),
#  ('Cállate', 122),
#  ('callate', 110),
#  ('inmigrantes', 102),
#  ('mujer', 96),
#  ('Callate', 91),
#  ('mereces', 82),
#  ('cállate', 78),
#  ('mierda', 75),
#  ('PUTA', 68),
#  ('mujeres', 57),
#  ('país', 54),
#  ('España', 54),
#  ('árabes', 53),
#  ('novia', 51),
#  ('subsaharianos', 50),
#  ('hija', 46),
#  ('vos', 44),
#  ('cara', 39),
#  ('indocumentados', 39),
#  ('inmigrante', 38),
#  ('culo', 36),
#  ('refugiados', 36),
#  ('PERRA', 35),
#  ('papeles', 35),
#  ('guarra', 34),
#  ('CALLATE', 33),
#  ('maldita', 33),
#  ('valla', 33),
#  ('sudaca', 32),
#  ('madre', 32),
#  ('vida', 32),
#  ('enseñar', 31),
#  ('manteros', 29),
#  ('pinche', 28),
#  ('Ceuta', 28),
#  ('españoles', 28),
#  ('ilegal', 28),
#  ('gente', 28),
#  ('sudacas', 27),
#  ('Puta', 27),
#  ('inmigración', 26),
#  ('tienes', 26),
#  ('años', 26),
#  ('ZORRA', 26),
#  ('casa', 25),
#  ('vienen', 24),
#  ('negros', 24),
#  ('árabe', 24),
#  ('hombre', 24),
#  ('polla', 23),
#  ('re', 22),
#  ('ilegales', 22),
#  ('sos', 22),
#  ('moros', 22),
#  ('putos', 21),
#  ('países', 21),
#  ('indocumentado', 21),
#  ('Perra', 20),
#  ('CÁLLATE', 20),
#  ('hijos', 19),
#  ('amor', 19),
#  ('negro', 19),
#  ('Barcelona', 19),
#  ('quiero', 19),
#  ('pasa', 19),
#  ('Europa', 19),
#  ('dinero', 19),
#  ('boca', 19),
#  ('año', 18),
#  ('moromierdas', 18),
#  ('calles', 18),
#  ('MIERDA', 18),
#  ('vía', 17),
#  ('gusta', 17),
#  ('chica', 17),
#  ('deja', 17),
#  ('acoso', 16),
#  ('callada', 16),
#  ('  ', 16),
#  ('venir', 15),
#  ('ve', 15),
#  ('cabeza', 15),
#  ('Marruecos', 15),
#  ('racista', 15),
#  ('tetas', 15),
#  ('mundo', 15),
#  ('odio', 15),
#  ('digo', 14),
#  ('amiga', 14),
#  ('güera', 14),
#  ('español', 14),
#  ('enseñando', 14),
#  ('vacaciones', 14),
#  ('gobierno', 13),
#  ('puto', 13),
#  ('niños', 13),
#  ('viene', 13),
#  ('gorda', 13),
#  ('quieren', 13),
#  ('arabes', 13),
#  ('jajaja', 13),
#  ('vivir', 13),
#  ('chinos', 12),
#  ('hombres', 12),
#  ('calle', 12),
#  ('gracias', 12),
#  ('güero', 12),
#  ('pendeja', 12),
#  ('vieja', 12),
#  ('merecía', 12),
#  ('tipo', 12),
#  ('coño', 12),
#  ('verga', 12),
#  ('negratas', 12),
#  ('asco', 12),
#  ('putas', 12),
#  ('Melilla', 12),
#  ('impuestos', 12),
#  ('mala', 12),
#  ('imbécil', 12),
#  ('alguien', 12),
#  ('vas', 12),
#  ('pa', 12),
#  ('anda', 12),
#  ('das', 11),
#  ('concha', 11),
#  ('guerra', 11),
#  ('subsahariano', 11),
#  ('@sanchezcastejon', 11),
#  ('ayudas', 11),
#  ('único', 11),
#  ('africanos', 11),
#  ('hermana', 11),
#  ('HIJA', 11),
#  ('entrar', 11),
#  ('falta', 11),
#  ('güeros', 11),
#  ('frente', 11),
#  ('sucia', 11),
#  ('GUARRA', 11),
#  ('millones', 11),
#  ('grupo', 11),
#  ('pueblo', 11),
#  ('cultura', 11),
#  ('sevillista', 10),
#  ('hablar', 10),
#  ('violar', 10),
#  ('cosa', 10),
#  ('turista', 10),
#  ('entran', 10),
#  ('cal', 10),
#  ('viva', 10),
#  ('paso', 10),
#  ('invasión', 10),
#  ('Venezuela', 10),
#  ('favor', 10),
#  ('dormir', 10),
#  ('pasar', 10),
#  ('INMIGRANTES', 10),
#  ('ESPAÑA', 10),
#  ('ilegalmente', 10),
#  ('barata', 10),
#  ('personas', 10),
#  ('gilipollas', 10),
#  ('venezolanos', 10),
#  ('tenes', 10),
#  ('origen', 10),
#  ('xq', 10),
#  ('mano', 9),
#  ('pagar', 9),
#  ('has', 9),
#  ('respeto', 9),
#  ('importa', 9),
#  ('Jajajaja', 9),
#  ('hijo', 9),
#  ('razón', 9),
#  ('culpa', 9),
#  ('basura', 9),
#  ('persona', 9),
#  ('amigo', 9),
#  ('visto', 9),
#  ('llegan', 9),
#  ('problema', 9),
#  ('merecías', 9),
#  ('MUJER', 9),
#  ('MADRE', 9),
#  ('loca', 9),
#  ('arabe', 9),
#  ('video', 9),
#  ('violentos', 9),
#  ('musulmanes', 9),
#  ('quiera', 9),
#  ('corazón', 9),
#  ('control', 8),
#  ('Gracias', 8),
#  ('Ay', 8),
#  ('racismo', 8),
#  ('ven', 8),
#  ('eh', 8),
#  ('diciendo', 8),
#  ('pasó', 8),
#  ('racistas', 8),
#  ('cuerpo', 8),
#  ('negra', 8),
#  ('joven', 8),
#  ('seguro', 8),
#  ('llama', 8),
#  ('Jajaja', 8),
#  ('dando', 8),
#  ('extranjeros', 8),
#  ('Árabes', 8),
#  ('pobre', 8),
#  ('iba', 8),
#  ('mil', 8),
#  ('Sos', 8),
#  ('espero', 8),
#  ('derechos', 8),
#  ('pendejos', 8),
#  ('fotos', 8),
#  ('estupida', 7),
#  ('Sánchez', 7),
#  ('pobres', 7),
#  ('pase', 7),
#  ('creen', 7),
#  ('ayudar', 7),
#  ('llega', 7),
#  ('vale', 7),
#  ('puso', 7),
#  ('menores', 7),
#  ('mina', 7),
#  ('pedazo', 7),
#  ('presidente', 7),
#  ('escote', 7),
#  ('siento', 7),
#  ('violaciones', 7),
#  ('asquerosa', 7),
#  ('problemas', 7),
#  ('turistas', 7),
#  ('perro', 7),
#  ('paises', 7),
#  ('ayuda', 7),
#  ('sanidad', 7),
#  ('jaja', 7),
#  ('delincuentes', 7),
#  ('violadores', 7),
#  ('ja', 7),
#  ('@lortegadiaz', 7),
#  ('Vos', 7),
#  ('doble', 7),
#  ('muerte', 7),
#  ('etc', 7),
#  ('familia', 7),
#  ('pena', 7),
#  ('matar', 7),
#  ('amo', 7),
#  ('mexicanos', 7),
#  ('estás', 7),
#  ('jóvenes', 7),
#  ('frontera', 7),
#  ('Dios', 6),
#  ('sistema', 6),
#  ('moromierda', 6),
#  ('ridículas', 6),
#  ('Adán', 6),
#  ('busca', 6),
#  ('violencia', 6),
#  ('costumbres', 6),
#  ('violación', 6),
#  ('jajajaja', 6),
#  ('atención', 6),
#  ('meses', 6),
#  ('Zorra', 6),
#  ('@lopezdoriga', 6),
#  ('canción', 6),
#  ('buscando', 6),
#  ('mafias', 6),
#  ('provocar', 6),
#  ('medidas', 6),
#  ('Hola', 6),
#  ('puedes', 6),
#  ('Hija', 6),
#  ('mama', 6),
#  ('esperan', 6),
#  ('mamá', 6),
#  ('cojones', 6),
#  ('Putos', 6),
#  ('veo', 6),
#  ('feliz', 6),
#  ('sexual', 6),
#  ('desgracia', 6),
#  ('sociales', 6),
#  ('gana', 6),
#  ('malparida', 6),
#  ('acá', 6),
#  ('musulmonos', 6),
#  ('RE', 6),
#  ('llamar', 6),
#  ('enseñarle', 6),
#  ('imbecil', 6),
#  ('Oye', 6),
#  ('unga', 6),
#  ('comer', 6),
#  ('vender', 6),
#  ('llamada', 6),
#  ('religión', 6),
#  ('viven', 6),
#  ('leyes', 6),
#  ('mayoría', 6),
#  ('20', 6),
#  ('sangre', 6),
#  ('escoria', 6),
#  ('tantos', 6),
#  ('MERECES', 6),
#  ('semen', 6),
#  ('sociedad', 6),
#  ('comida', 6),
#  ('totalmente', 6),
#  ('Madrid', 6),
#  ('cuento', 6),
#  ('sacar', 6),
#  ('mitad', 6),
#  ('pagan', 6),
#  ('novio', 6),
#  ('darle', 6),
#  ('bla', 6),
#  ('venezolano', 5),
#  ('@DrodriguezVen', 5),
#  ('dejar', 5),
#  ('fregar', 5),
#  ('hocico', 5),
#  ('robar', 5),
#  ('libertad', 5),
#  ('-Porque', 5),
#  ('cambio', 5),
#  ('sexo', 5),
#  ('casos', 5),
#  ('queda', 5),
#  ('metro', 5),
#  ('izquierda', 5),
#  ('agresión', 5),
#  ('recoger', 5),
#  ('animales', 5),
#  ('etc.', 5),
#  ('perfecta', 5),
#  ('acaba', 5),
#  ('señor', 5),
#  ('cerda', 5),
#  ('VAS', 5),
#  ('puse', 5),
#  ('40.000', 5),
#  ('coche', 5),
#  ('maltrato', 5),
#  ('foto', 5),
#  ('realidad', 5),
#  ('sigues', 5),
#  ('voz', 5),
#  ('gringo', 5),
#  ('cree', 5),
#  ('entrada', 5),
#  ('barrio', 5),
#  ('niño', 5),
#  ('fuertes', 5),
#  ('chupa', 5),
#  ('pija', 5),
#  ('rico', 5),
#  ('caliente', 5),
#  ('agredido', 5),
#  ('productos', 5),
#  ('Pablo', 5),
#  ('INVASION', 5),
#  ('gratis', 5),
#  ('MALDITA', 5),
#  ('@BeeluArzola', 5),
#  ('ido', 5),
#  ('pedo', 5),
#  ('super', 5),
#  ('enorme', 5),
#  ('inteligencia', 5),
#  ('dije', 5),
#  ('cárcel', 5),
#  ('emigrantes', 5),
#  ('vives', 5),
#  ('llaman', 5),
#  ('gringos', 5),
#  ('10', 5),
#  ('joder', 5),
#  ('dices', 5),
#  ('calor', 5),
#  ('CARA', 5),
#  ('alta', 5),
#  ('quieres', 5),
#  ('ILEGALES', 5),
#  ('pone', 5),
#  ('encanta', 5),
#  ('libre', 5),
#  ('ojos', 5),
#  ('comercios', 5),
#  ('marroquíes', 5),
#  ('estúpida', 5),
#  ('patera', 5),
#  ('   ', 5),
#  ('asesinos', 5),
#  ('fea', 5),
#  ('masiva', 5),
#  ('DIOS', 5),
#  ('toca', 5),
#  ('extranjero', 5),
#  ('@NicolasMaduro', 5),
#  ('gay', 5),
#  ('Pon', 5),
#  ('pon', 5),
#  ('invasores', 5),
#  ('cerebro', 5),
#  ('pasta', 5),
#  ('bonita', 5),
#  ('Pedro', 5),
#  ('partido', 5),
#  ('JAJAJA', 5),
#  ('sirvienta', 5),
#  ('huevos', 5),
#  ('lastima', 5),
#  ('come', 5),
#  ('CASA', 5),
#  ('chicas', 5),
#  ('\u2066@sanchezcastejon\u2069', 5),
#  ('pide', 5),
#  ('expulsar', 5),
#  ('falda', 5),
#  ('tierra', 5),
#  ('Sudacas', 5),
#  ('quitan', 5),
#  ('civiles', 5),
#  ('chiste', 5),
#  ('políticos', 5),
#  ('quejan', 5),
#  ('hubiera', 5),
#  ('autoridades', 5),
#  ('gordo', 5),
#  ('mar', 5),
#  ('ley', 5),
#  ('ponen', 5),
#  ('par', 5),
#  ('noche', 5),
#  ('hermano', 5),
#  ('manos', 5),
#  ('deberían', 5),
#  ('cagada', 4),
#  ('hablando', 4),
#  ('negocios', 4),
#  ('Acá', 4),
#  ('vaina', 4),
#  ('hagas', 4),
#  ('ay', 4),
#  ('musulmono', 4),
#  ('violenta', 4),
#  ('espaldas', 4),
#  ('Twitter', 4),
#  ('humano', 4),
#  ('invadir', 4),
#  ('semana', 4),
#  ('@pablocasado', 4),
#  ('SUDACA', 4),
#  ('orto', 4),
#  ('Españoles', 4),
#  ('@ahorapodemos', 4),
#  ('americano', 4),
#  ('guardia', 4),
#  ('civil', 4),
#  ('Franco', 4),
#  ('malo', 4),
#  ('regla', 4),
#  ('social', 4),
#  ('política', 4),
#  ('jamás', 4),
#  ('fronteras', 4),
#  ('agrede', 4),
#  ('inteligente', 4),
#  ('sitio', 4),
#  ('africana', 4),
#  ('parida', 4),
#  ('desgraciada', 4),
#  ('debería', 4),
#  ('acoger', 4),
#  ('forma', 4),
#  ('española', 4),
#  ('morir', 4),
#  ('pueblos', 4),
#  ('tanta', 4),
#  ('cocina', 4),
#  ('vestido', 4),
#  ('vino', 4),
#  ('plan', 4),
#  ('extraño', 4),
#  ('llevan', 4),
#  ('nigeriano', 4),
#  ('personalidad', 4),
#  ('trabajando', 4),
#  ('quitarnos', 4),
#  ('abajo', 4),
#  ('seguridad', 4),
#  ('universal', 4),
#  ('Italia', 4),
#  ('Milán', 4),
#  ('ASCO', 4),
#  ('SUDACAS', 4),
#  ('andan', 4),
#  ('marroquí', 4),
#  ('Siria', 4),
#  ('estén', 4),
#  ('jugar', 4),
#  ('parecen', 4),
#  ('papá', 4),
#  ('hdp', 4),
#  ('rata', 4),
#  ('to', 4),
#  ('CALLES', 4),
#  ('animal', 4),
#  ('Quiero', 4),
#  ('pinches', 4),
#  ('subvenciones', 4),
#  ('pario', 4),
#  ('Sanidad', 4),
#  ('vergüenza', 4),
#  ('15', 4),
#  ('Ojalá', 4),
#  ('juego', 4),
#  ('feminazis', 4),
#  ('ponte', 4),
#  ('moral', 4),
#  ('inmigracion', 4),
#  ('legal', 4),
#  ('seas', 4),
#  ('vendiendo', 4),
#  ('fuerza', 4),
#  ('Jajajajaja', 4),
#  ('ok', 4),
#  ('mierdas', 4),
#  ('vengan', 4),
#  ('llorar', 4),
#  ('saltan', 4),
#  ('montón', 4),
#  ('machismo', 4),
#  ('progres', 4),
#  ('600', 4),
#  ('salvajes', 4),
#  ('compartir', 4),
#  ('político', 4),
#  ('cargo', 4),
#  ('comprar', 4),
#  ('horrible', 4),
#  ('EUROPA', 4),
#  ('meter', 4),
#  ('lesbiana', 4),
#  ('Pinche', 4),
#  ('unico', 4),
#  ('sudaka', 4),
#  ('Ven', 4),
#  ('@elisacarrio', 4),
#  ('ladrona', 4),
#  ('asesina', 4),
#  ('favorita', 4),
#  ('ratera', 4),
#  ('asqueroso', 4),
#  ('virgen', 4),
#  ('pelo', 4),
#  ('garganta', 4),
#  ('comentario', 4),
#  ('migrantes', 4),
#  ('quieran', 4),
#  ('caca', 4),
#  ('esperando', 4),
#  ('Colau', 4),
#  ('cabron', 4),
#  ('venga', 4),
#  ('blanco', 4),
#  ('pelotuda', 4),
#  ('jodiendo', 4),
#  ('venezuela', 4),
#  ('traen', 4),
#  ('pasan', 4),
#  ('pongo', 4),
#  ('@marianorajoy', 4),
#  ('musulmana', 4),
#  ('tonterías', 4),
#  ('Alemania', 4),
#  ('vete', 4),
#  ('tenías', 4),
#  ('drogas', 4),
#  ('ahre', 4),
#  ('violador', 4),
#  ('ministro', 4),
#  ('putita', 4),
#  ('PENDEJA', 4),
#  ('diste', 4),
#  ('@policia', 4),
#  ('esperar', 4),
#  ('@sebastianpinera', 4),
#  ('puesto', 4),
#  ('darte', 4),
#  ('europea', 4),
#  ('Español', 4),
#  ('niña', 4),
#  ('entrado', 4),
#  ('ciudadanos', 4),
#  ('NEGROS', 4),
#  ('tremenda', 4),
#  ('muralla', 4),
#  ('hambre', 4),
#  ('infierno', 4),
#  ('cama', 4),
#  ('fama', 4),
#  ('punto', 4),
#  ('entiendo', 4),
#  ('manada', 4),
#  ('decís', 4),
#  ('mantero', 4),
#  ('pedir', 4),
#  ('siquiera', 4),
#  ('rica', 4),
#  ('miles', 4),
#  ('100.000', 4),
#  ('suerte', 4),
#  ('derecho', 4),
#  ('señora', 4),
#  ('Arabe', 4),
#  ('vecinos', 4),
#  ('mañana', 4),
#  ('@salvameoficial', 4),
#  ('delinquir', 4),
#  ('idiota', 4),
#  ('ciudad', 4),
#  ('terroristas', 4),
#  ('Grande', 4),
#  ('guardias', 4),
#  ('libro', 4),
#  ('andar', 4),
#  ('asalto', 4),
#  ('mentirosa', 4),
#  ('CONCHA', 4),
#  ('espera', 4),
#  ('odian', 4),
#  ('ganar', 4),
#  ('campaña', 4),
#  ('Inmigración', 4),
#  ('terrorista', 4),
#  ('Perú', 4),
#  ('DELINCUENTES', 4),
#  ('pones', 4),
#  ('feminista', 4),
#  ('condena', 4),
#  ('seguir', 4),
#  ('prietos', 4),
#  ('economía', 4),
#  ('perfil', 4),
#  ('sigo', 4),
#  ('Mira', 4),
#  ('malditos', 4),
#  ('trola', 4),
#  ('Venezolanos', 4),
#  ('hora', 4),
#  ('envidiosa', 4),
#  ('nombre', 4),
#  ('VALLA', 4),
#  ('lista', 4),
#  ('sale', 4),
#  ('avión', 3),
#  ('miserables', 3),
#  ('jodidos', 3),
#  ('perras', 3),
#  ('paga', 3),
#  ('factura', 3),
#  ('sueltos', 3),
#  ('votantes', 3),
#  ('maldad', 3),
#  ('Aprende', 3),
#  ('pensiones', 3),
#  ('sanitario', 3),
#  ('LOCA', 3),
#  ('inteligentes', 3),
#  ('revés', 3),
#  ('latinos', 3),
#  ('peleas', 3),
#  ('plena', 3),
#  ('JAJAJAJAJAJA', 3),
#  ('Facebook', 3),
#  ('@20', 3),
#  ('dejan', 3),
#  ('policía', 3),
#  ('niñas', 3),
#  ('sorprende', 3),
#  ('podes', 3),
#  ('querés', 3),
#  ('explicar', 3),
#  ('porno', 3),
#  ('pies', 3),
#  ('Negros', 3),
#  ('puedan', 3),
#  ('oye', 3),
#  ('paliza', 3),
#  ('solución', 3),
#  ('puro', 3),
#  ('cristianos', 3),
#  ('2017', 3),
#  ('chico', 3),
#  ('género', 3),
#  ('Pregunta', 3),
#  ('nota', 3),
#  ('inglés', 3),
#  ('África', 3),
#  ('borracha', 3),
#  ('@elmundoes', 3),
#  ('@Juandedios_P', 3),
#  ('@KimberlyLoaiza', 3),
#  ('hables', 3),
#  ('dale', 3),
#  ('palo', 3),
#  ('muerta', 3),
#  ('REFUGIADOS', 3),
#  ('españa', 3),
#  ('aguantar', 3),
#  ('pretende', 3),
#  ('roba', 3),
#  ('Ojala', 3),
#  ('esposa', 3),
#  ('pensado', 3),
#  ('Moncloa', 3),
#  ('Mami', 3),
#  ('Coño', 3),
#  ('deseo', 3),
#  ('frío', 3),
#  ('joda', 3),
#  ('completa', 3),
#  ('real', 3),
#  ('ESPAÑOLES', 3),
#  ('di', 3),
#  ('pene', 3),
#  ('cabrona', 3),
#  ('querido', 3),
#  ('tonterias', 3),
#  ('pimienta', 3),
#  ('estación', 3),
#  ('oportunidades', 3),
#  ('culpable', 3),
#  ('opines', 3),
#  ('idea', 3),
#  ('redes', 3),
#  ('cae', 3),
#  ('hp', 3),
#  ('ah', 3),
#  ('cuchillo', 3),
#  ('Mujer', 3),
#  ('convertir', 3),
#  ('viejas', 3),
#  ('reciben', 3),
#  ('castigo', 3),
#  ('agua', 3),
#  ('PARIO', 3),
#  ('agreden', 3),
#  ('GOBIERNO', 3),
#  ('vuelta', 3),
#  ('Alarma', 3),
#  ('50.000', 3),
#  ('MUNDO', 3),
#  ('lpm', 3),
#  ('escuelas', 3),
#  ('parió', 3),
#  ('SEMEN', 3),
#  ('sarnosa', 3),
#  ('toman', 3),
#  ('metas', 3),
#  ('cariño', 3),
#  ('vayas', 3),
#  ('olvida', 3),
#  ('medias', 3),
#  ('reír', 3),
#  ('estes', 3),
#  ('aparte', 3),
#  ('Sudaca', 3),
#  ('obvio', 3),
#  ('sur', 3),
#  ('leer', 3),
#  ('defienden', 3),
#  ('menuda', 3),
#  ('pinta', 3),
#  ('mira', 3),
#  ('@vikidonda', 3),
#  ('chat', 3),
#  ('llamamos', 3),
#  ('resto', 3),
#  ('Alguien', 3),
#  ('Subsaharianos', 3),
#  ('@juliamengo', 3),
#  ('Casado', 3),
#  ('quería', 3),
#  ('pateras', 3),
#  ('mando', 3),
#  ("Don't", 3),
#  ('call', 3),
#  ('beaner', 3),
#  ('digas', 3),
#  ('puñetero', 3),
#  ('abrir', 3),
#  ('jajajajajaja', 3),
#  ('página', 3),
#  ('enseñaré', 3),
#  ('vi', 3),
#  ('delincuente', 3),
#  ('corrupta', 3),
#  ('guapa', 3),
#  ('público', 3),
#  ('hostia', 3),
#  ('opinión', 3),
#  ('Espana', 3),
#  ('recibir', 3),
#  ('tí', 3),
#  ('Estás', 3),
#  ('patética', 3),
#  ('tesis', 3),
#  ('atacan', 3),
#  ('casas', 3),
#  ('acogida', 3),
#  ('extrañas', 3),
#  ('merece', 3),
#  ('pensar', 3),
#  ('dejas', 3),
#  ('tonto', 3),
#  ('abierta', 3),
#  ('salir', 3),
#  ('nacional', 3),
#  ('oro', 3),
#  ('TIPO', 3),
#  ('llevo', 3),
#  ('2018', 3),
#  ('maravilloso', 3),
#  ('venden', 3),
#  ('serio', 3),
#  ('respeta', 3),
#  ('insulto', 3),
#  ('Gobierno', 3),
#  ('policial', 3),
#  ('@Elperiodico', 3),
#  ('noticias', 3),
#  ('legales', 3),
#  ('digan', 3),
#  ('Baby', 3),
#  ('diez', 3),
#  ('rápido', 3),
#  ('Lástima', 3),
#  ('AMIGA', 3),
#  ('oficial', 3),
#  ('PUTOS', 3),
#  ('caga', 3),
#  ('culiao', 3),
#  ('nomas', 3),
#  ('insultando', 3),
#  ('judíos', 3),
#  ('raza', 3),
#  ('buscar', 3),
#  ('gentuza', 3),
#  ('@guardiacivil', 3),
#  ('feministas', 3),
#  ('salió', 3),
#  ('MILES', 3),
#  ('INMIGRACION', 3),
#  ('ILEGAL', 3),
#  ('StopInvasion', 3),
#  ('MOROS', 3),
#  ('jefe', 3),
#  ('JAJAJAJAJAJAJAJA', 3),
#  ('traidor', 3),
#  ('deporten', 3),
#  ('mensaje', 3),
#  ('muro', 3),
#  ('paguita', 3),
#  ('fiesta', 3),
#  ('cabello', 3),
#  ('nacionalidad', 3),
#  ('crees', 3),
#  ('tema', 3),
#  ('Chinos', 3),
#  ('miedo', 3),
#  ('maduro', 3),
#  ('apoyo', 3),
#  ('delito', 3),
#  ('25', 3),
#  ('agrediendo', 3),
#  ('femenino', 3),
#  ('jajajajaj', 3),
#  ('saltado', 3),
#  ('cubanos', 3),
#  ('ataques', 3),
#  ('Seguro', 3),
#  ('cuesta', 3),
#  ('imagino', 3),
#  ('vuelvan', 3),
#  ('tío', 3),
#  ('cruzar', 3),
#  ('diga', 3),
#  ('ángel', 3),
#  ('prensa', 3),
#  ('saltando', 3),
#  ('cabe', 3),
#  ('HDP', 3),
#  ('patada', 3),
#  ('semejante', 3),
#  ('defender', 3),
#  ('llamando', 3),
#  ('divina', 3),
#  ('quedar', 3),
#  ('salido', 3),
#  ('llorando', 3),
#  ('tia', 3),
#  ('efecto', 3),
#  ('YEGUA', 3),
#  ('cesants', 3),
#  ('desempleo', 3),
#  ('aumento', 3),
#  ('laboral', 3),
#  ('Sigan', 3),
#  ('nación', 3),
#  ('UE', 3),
#  ('traer', 3),
#  ('tengan', 3),
#  ('violentamente', 3),
#  ('@Barbijaputa', 3),
#  ('empieza', 3),
#  ('decis', 3),
#  ('irse', 3),
#  ('400', 3),
#  ('ves', 3),
#  ('ojala', 3),
#  ('pasando', 3),
#  ('acabar', 3),
#  ('vuelven', 3),
#  ('PARIDA', 3),
#  ('whatsapp', 3),
#  ('cola', 3),
#  ('Marlaska', 3),
#  ('inmediatamente', 3),
#  ('mundial', 3),
#  ('hijas', 3),
#  ('Seguridad', 3),
#  ('50', 3),
#  ('Vía', 3),
#  ('Perdón', 3),
#  ('sindicato', 3),
#  ('Trump', 3),
#  ('recursos', 3),
#  ('twitter', 3),
#  ('pilla', 3),
#  ('abuelo', 3),
#  ('llenar', 3),
#  ('Carmena', 3),
#  ('asaltar', 3),
#  ('dedos', 3),
#  ('piden', 3),
#  ('presencia', 3),
#  ('12', 3),
#  ('norteamericana', 3),
#  ('advierte', 3),
#  ('inminente', 3),
#  ('mentira', 3),
#  ('México', 3),
#  ('tiro', 3),
#  ('habría', 3),
#  ('vende', 3),
#  ('patria', 3),
#  ('fácil', 3),
#  ('única', 3),
#  ('oh', 3),
#  ('INMIGRACIÓN', 3),
#  ('PUTO', 3),
#  ('regalo', 3),
#  ('sabia', 3),
#  ('ropa', 3),
#  ('pinché', 3),
#  ('blancos', 3),
#  ('justicia', 3),
#  ('banco', 3),
#  ('Guarra', 3),
#  ('podrido', 3),
#  ('necesita', 3),
#  ('presa', 3),
#  ('luz', 3),
#  ('turismo', 3),
#  ('Indocumentados', 3),
#  ('profesional', 3),
#  ('pack', 3),
#  ('Mereces', 3),
#  ('huele', 3),
#  ('pollas', 3),
#  ('carajo', 3),
#  ('sueldos', 3),
#  ('cretino', 3),
#  ('pregunta', 3),
#  ('caos', 3),
#  ('MIRA', 3),
#  ...]

# %% [markdown]
# #### 1.2 Word Frequecy for Examples that are Hate Speech and Aggressive

# %%
freqs = slice_dataframe_and_compute_word_frequency(df, ['HS', 'AG'], [1, 1], 'text', 'es_core_news_sm')
freqs.most_common()[:10]
# Out:
# Found a total of 1502 examples
# [('puta', 398),
#  ('perra', 322),
#  ('zorra', 207),
#  ('Cállate', 122),
#  ('callate', 109),
#  ('Callate', 90),
#  ('mereces', 80),
#  ('cállate', 78),
#  ('mierda', 74),
#  ('PUTA', 67),
#  ('inmigrantes', 66),
#  ('novia', 49),
#  ('hija', 45),
#  ('vos', 44),
#  ('mujer', 42),
#  ('árabes', 40),
#  ('país', 37),
#  ('España', 37),
#  ('cara', 35),
#  ('PERRA', 34),
#  ('CALLATE', 33),
#  ('maldita', 33),
#  ('culo', 31),
#  ('madre', 30),
#  ('refugiados', 29),
#  ('pinche', 27),
#  ('subsaharianos', 27),
#  ('enseñar', 27),
#  ('Puta', 27),
#  ('guarra', 26),
#  ('ZORRA', 26),
#  ('mujeres', 25),
#  ('vida', 25),
#  ('indocumentados', 25),
#  ('inmigrante', 23),
#  ('re', 22),
#  ('sudaca', 21),
#  ('ilegal', 21),
#  ('valla', 21),
#  ('tienes', 20),
#  ('españoles', 20),
#  ('CÁLLATE', 20),
#  ('putos', 19),
#  ('países', 19),
#  ('Perra', 19),
#  ('papeles', 19),
#  ('sos', 19),
#  ('boca', 19),
#  ('Ceuta', 19),
#  ('polla', 19),
#  ('manteros', 18),
#  ('moros', 18),
#  ('MIERDA', 18),
#  ('sudacas', 17),
#  ('negros', 17),
#  ('indocumentado', 17),
#  ('años', 17),
#  ('negro', 16),
#  ('quiero', 16),
#  ('moromierdas', 16),
#  ('vienen', 16),
#  ('árabe', 16),
#  ('deja', 16),
#  ('gente', 16),
#  ('inmigración', 16),
#  ('hijos', 15),
#  ('callada', 15),
#  ('pasa', 15),
#  ('año', 15),
#  ('odio', 15),
#  ('casa', 15),
#  ('ve', 14),
#  ('calles', 14),
#  ('chica', 14),
#  ('Barcelona', 13),
#  ('gusta', 13),
#  ('Europa', 13),
#  ('amor', 12),
#  ('amiga', 12),
#  ('vía', 12),
#  ('pendeja', 12),
#  ('  ', 12),
#  ('gorda', 12),
#  ('dinero', 12),
#  ('verga', 12),
#  ('racista', 12),
#  ('ilegales', 12),
#  ('jajaja', 12),
#  ('imbécil', 12),
#  ('alguien', 12),
#  ('vas', 12),
#  ('pa', 12),
#  ('anda', 12),
#  ('puto', 11),
#  ('digo', 11),
#  ('concha', 11),
#  ('niños', 11),
#  ('HIJA', 11),
#  ('español', 11),
#  ('hombre', 11),
#  ('enseñando', 11),
#  ('sucia', 11),
#  ('GUARRA', 11),
#  ('das', 10),
#  ('@sanchezcastejon', 10),
#  ('dormir', 10),
#  ('merecía', 10),
#  ('gobierno', 10),
#  ('venir', 10),
#  ('hermana', 10),
#  ('gilipollas', 10),
#  ('frente', 10),
#  ('asco', 10),
#  ('vieja', 10),
#  ('grupo', 10),
#  ('mala', 10),
#  ('tenes', 10),
#  ('tetas', 10),
#  ('sevillista', 9),
#  ('chinos', 9),
#  ('hablar', 9),
#  ('Jajajaja', 9),
#  ('culpa', 9),
#  ('basura', 9),
#  ('amigo', 9),
#  ('turista', 9),
#  ('cal', 9),
#  ('viva', 9),
#  ('único', 9),
#  ('merecías', 9),
#  ('barata', 9),
#  ('MUJER', 9),
#  ('MADRE', 9),
#  ('Marruecos', 9),
#  ('negratas', 9),
#  ('cabeza', 9),
#  ('loca', 9),
#  ('güera', 9),
#  ('impuestos', 9),
#  ('putas', 9),
#  ('vivir', 9),
#  ('millones', 9),
#  ('vacaciones', 9),
#  ('mano', 8),
#  ('respeto', 8),
#  ('violar', 8),
#  ('gracias', 8),
#  ('hijo', 8),
#  ('cosa', 8),
#  ('persona', 8),
#  ('llegan', 8),
#  ('eh', 8),
#  ('entran', 8),
#  ('paso', 8),
#  ('Venezuela', 8),
#  ('viene', 8),
#  ('africanos', 8),
#  ('pasar', 8),
#  ('calle', 8),
#  ('güero', 8),
#  ('coño', 8),
#  ('Jajaja', 8),
#  ('subsahariano', 8),
#  ('video', 8),
#  ('Melilla', 8),
#  ('arabes', 8),
#  ('entrar', 8),
#  ('mil', 8),
#  ('corazón', 8),
#  ('Sos', 8),
#  ('pendejos', 8),
#  ('importa', 7),
#  ('estupida', 7),
#  ('pagar', 7),
#  ('ayudas', 7),
#  ('favor', 7),
#  ('problema', 7),
#  ('pedazo', 7),
#  ('ESPAÑA', 7),
#  ('cuerpo', 7),
#  ('tipo', 7),
#  ('asquerosa', 7),
#  ('llama', 7),
#  ('perro', 7),
#  ('ayuda', 7),
#  ('violentos', 7),
#  ('musulmanes', 7),
#  ('pobre', 7),
#  ('iba', 7),
#  ('falta', 7),
#  ('quiera', 7),
#  ('@lortegadiaz', 7),
#  ('Vos', 7),
#  ('origen', 7),
#  ('pueblo', 7),
#  ('mundo', 7),
#  ('ilegalmente', 7),
#  ('espero', 7),
#  ('seguro', 7),
#  ('güeros', 7),
#  ('has', 6),
#  ('Ay', 6),
#  ('guerra', 6),
#  ('violación', 6),
#  ('jajajaja', 6),
#  ('ayudar', 6),
#  ('llega', 6),
#  ('vale', 6),
#  ('Zorra', 6),
#  ('@lopezdoriga', 6),
#  ('racistas', 6),
#  ('provocar', 6),
#  ('mina', 6),
#  ('Hija', 6),
#  ('mamá', 6),
#  ('siento', 6),
#  ('Putos', 6),
#  ('feliz', 6),
#  ('malparida', 6),
#  ('racismo', 6),
#  ('musulmonos', 6),
#  ('RE', 6),
#  ('imbecil', 6),
#  ('Oye', 6),
#  ('jaja', 6),
#  ('delincuentes', 6),
#  ('Árabes', 6),
#  ('razón', 6),
#  ('violadores', 6),
#  ('leyes', 6),
#  ('acoso', 6),
#  ('INMIGRANTES', 6),
#  ('muerte', 6),
#  ('escoria', 6),
#  ('MERECES', 6),
#  ('semen', 6),
#  ('familia', 6),
#  ('pena', 6),
#  ('matar', 6),
#  ('amo', 6),
#  ('etc', 6),
#  ('mexicanos', 6),
#  ('quieren', 6),
#  ('estás', 6),
#  ('darle', 6),
#  ('bla', 6),
#  ('venezolano', 5),
#  ('@DrodriguezVen', 5),
#  ('hocico', 5),
#  ('moromierda', 5),
#  ('Adán', 5),
#  ('Sánchez', 5),
#  ('pobres', 5),
#  ('canción', 5),
#  ('mafias', 5),
#  ('Hola', 5),
#  ('puedes', 5),
#  ('cerda', 5),
#  ('VAS', 5),
#  ('puse', 5),
#  ('mama', 5),
#  ('puso', 5),
#  ('ven', 5),
#  ('cojones', 5),
#  ('sigues', 5),
#  ('desgracia', 5),
#  ('gringo', 5),
#  ('personas', 5),
#  ('gana', 5),
#  ('acá', 5),
#  ('negra', 5),
#  ('niño', 5),
#  ('violaciones', 5),
#  ('enseñarle', 5),
#  ('paises', 5),
#  ('chupa', 5),
#  ('pija', 5),
#  ('caliente', 5),
#  ('venezolanos', 5),
#  ('INVASION', 5),
#  ('MALDITA', 5),
#  ('@BeeluArzola', 5),
#  ('extranjeros', 5),
#  ('vender', 5),
#  ('dije', 5),
#  ('llaman', 5),
#  ('gringos', 5),
#  ('comer', 5),
#  ('joder', 5),
#  ('ja', 5),
#  ('CARA', 5),
#  ('libre', 5),
#  ('arabe', 5),
#  ('estúpida', 5),
#  ('fea', 5),
#  ('masiva', 5),
#  ('DIOS', 5),
#  ('extranjero', 5),
#  ('gay', 5),
#  ('Pon', 5),
#  ('pon', 5),
#  ('invasores', 5),
#  ('bonita', 5),
#  ('JAJAJA', 5),
#  ('comida', 5),
#  ('huevos', 5),
#  ('lastima', 5),
#  ('come', 5),
#  ('CASA', 5),
#  ('pasó', 5),
#  ('chicas', 5),
#  ('\u2066@sanchezcastejon\u2069', 5),
#  ('sacar', 5),
#  ('novio', 5),
#  ('gordo', 5),
#  ('hermano', 5),
#  ('fotos', 5),
#  ('cagada', 4),
#  ('negocios', 4),
#  ('hagas', 4),
#  ('ay', 4),
#  ('Dios', 4),
#  ('musulmono', 4),
#  ('espaldas', 4),
#  ('Twitter', 4),
#  ('ridículas', 4),
#  ('busca', 4),
#  ('invadir', 4),
#  ('casos', 4),
#  ('violencia', 4),
#  ('semana', 4),
#  ('orto', 4),
#  ('visto', 4),
#  ('americano', 4),
#  ('guardia', 4),
#  ('civil', 4),
#  ('Franco', 4),
#  ('malo', 4),
#  ('social', 4),
#  ('queda', 4),
#  ('recoger', 4),
#  ('buscando', 4),
#  ('menores', 4),
#  ('parida', 4),
#  ('desgraciada', 4),
#  ('perfecta', 4),
#  ('morir', 4),
#  ('acaba', 4),
#  ('vestido', 4),
#  ('escote', 4),
#  ('extraño', 4),
#  ('trabajando', 4),
#  ('maltrato', 4),
#  ('veo', 4),
#  ('foto', 4),
#  ('ASCO', 4),
#  ('voz', 4),
#  ('jugar', 4),
#  ('papá', 4),
#  ('hdp', 4),
#  ('rata', 4),
#  ('cree', 4),
#  ('pinches', 4),
#  ('pario', 4),
#  ('barrio', 4),
#  ('vergüenza', 4),
#  ('ponte', 4),
#  ('moral', 4),
#  ('seas', 4),
#  ('rico', 4),
#  ('fuerza', 4),
#  ('Jajajajaja', 4),
#  ('ok', 4),
#  ('mierdas', 4),
#  ('llorar', 4),
#  ('dando', 4),
#  ('progres', 4),
#  ('600', 4),
#  ('político', 4),
#  ('sanidad', 4),
#  ('productos', 4),
#  ('llamar', 4),
#  ('atención', 4),
#  ('comprar', 4),
#  ('Pablo', 4),
#  ('meter', 4),
#  ('Pinche', 4),
#  ('unico', 4),
#  ('ido', 4),
#  ('Ven', 4),
#  ('@elisacarrio', 4),
#  ('ladrona', 4),
#  ('asesina', 4),
#  ('pedo', 4),
#  ('ratera', 4),
#  ('super', 4),
#  ('virgen', 4),
#  ('pelo', 4),
#  ('enorme', 4),
#  ('garganta', 4),
#  ('comentario', 4),
#  ('cárcel', 4),
#  ('emigrantes', 4),
#  ('quieran', 4),
#  ('religión', 4),
#  ('vives', 4),
#  ('caca', 4),
#  ('venga', 4),
#  ('pelotuda', 4),
#  ('jodiendo', 4),
#  ('venezuela', 4),
#  ('medidas', 4),
#  ('dices', 4),
#  ('traen', 4),
#  ('alta', 4),
#  ('quieres', 4),
#  ('ILEGALES', 4),
#  ('pone', 4),
#  ('@marianorajoy', 4),
#  ('diciendo', 4),
#  ('sangre', 4),
#  ('vete', 4),
#  ('control', 4),
#  ('patera', 4),
#  ('   ', 4),
#  ('drogas', 4),
#  ('asesinos', 4),
#  ('ministro', 4),
#  ('putita', 4),
#  ('PENDEJA', 4),
#  ('diste', 4),
#  ('@policia', 4),
#  ('tantos', 4),
#  ('@NicolasMaduro', 4),
#  ('darte', 4),
#  ('xq', 4),
#  ('tremenda', 4),
#  ('muralla', 4),
#  ('hambre', 4),
#  ('infierno', 4),
#  ('punto', 4),
#  ('entiendo', 4),
#  ('manada', 4),
#  ('decís', 4),
#  ('Gracias', 4),
#  ('sirvienta', 4),
#  ('siquiera', 4),
#  ('cultura', 4),
#  ('derechos', 4),
#  ('problemas', 4),
#  ('@salvameoficial', 4),
#  ('tierra', 4),
#  ('mayoría', 4),
#  ('delinquir', 4),
#  ('terroristas', 4),
#  ('toca', 4),
#  ('guardias', 4),
#  ('civiles', 4),
#  ('Madrid', 4),
#  ('pagan', 4),
#  ('andar', 4),
#  ('mentirosa', 4),
#  ('CONCHA', 4),
#  ('odian', 4),
#  ('Inmigración', 4),
#  ('jóvenes', 4),
#  ('DELINCUENTES', 4),
#  ('sociedad', 4),
#  ('mar', 4),
#  ('pase', 4),
#  ('prietos', 4),
#  ('cuento', 4),
#  ('perfil', 4),
#  ('noche', 4),
#  ('totalmente', 4),
#  ('sigo', 4),
#  ('Mira', 4),
#  ('costumbres', 4),
#  ('Venezolanos', 4),
#  ('envidiosa', 4),
#  ('libertad', 4),
#  ('manos', 4),
#  ('deberían', 4),
#  ('joven', 4),
#  ('sale', 4),
#  ('frontera', 4),
#  ('Acá', 3),
#  ('vaina', 3),
#  ('perras', 3),
#  ('maldad', 3),
#  ('Aprende', 3),
#  ('robar', 3),
#  ('sistema', 3),
#  ('sanitario', 3),
#  ('LOCA', 3),
#  ('latinos', 3),
#  ('JAJAJAJAJAJA', 3),
#  ('Facebook', 3),
#  ('@20', 3),
#  ('humano', 3),
#  ('dejan', 3),
#  ('sorprende', 3),
#  ('podes', 3),
#  ('meses', 3),
#  ('querés', 3),
#  ('Españoles', 3),
#  ('oye', 3),
#  ('invasión', 3),
#  ('regla', 3),
#  ('política', 3),
#  ('inglés', 3),
#  ('sitio', 3),
#  ('borracha', 3),
#  ('@Juandedios_P', 3),
#  ('@KimberlyLoaiza', 3),
#  ('hables', 3),
#  ('dale', 3),
#  ('palo', 3),
#  ('muerta', 3),
#  ('aguantar', 3),
#  ('pretende', 3),
#  ('Ojala', 3),
#  ('plan', 3),
#  ('Mami', 3),
#  ('deseo', 3),
#  ('frío', 3),
#  ('joda', 3),
#  ('quitarnos', 3),
#  ('ESPAÑOLES', 3),
#  ('cabrona', 3),
#  ('querido', 3),
#  ('universal', 3),
#  ('SUDACAS', 3),
#  ('oportunidades', 3),
#  ('culpable', 3),
#  ('opines', 3),
#  ('to', 3),
#  ('CALLES', 3),
#  ('redes', 3),
#  ('sociales', 3),
#  ('sexo', 3),
#  ('hp', 3),
#  ('ah', 3),
#  ('castigo', 3),
#  ('española', 3),
#  ('PARIO', 3),
#  ('GOBIERNO', 3),
#  ('vuelta', 3),
#  ('esperan', 3),
#  ('MUNDO', 3),
#  ('lpm', 3),
#  ('Ojalá', 3),
#  ('parió', 3),
#  ('fuertes', 3),
#  ('sarnosa', 3),
#  ('metas', 3),
#  ('cariño', 3),
#  ('vayas', 3),
#  ('olvida', 3),
#  ('reír', 3),
#  ('estes', 3),
#  ('Sudaca', 3),
#  ('subvenciones', 3),
#  ('obvio', 3),
#  ('salvajes', 3),
#  ('compartir', 3),
#  ('agredido', 3),
#  ('menuda', 3),
#  ('pinta', 3),
#  ('mira', 3),
#  ('@vikidonda', 3),
#  ('chat', 3),
#  ('llamamos', 3),
#  ('@juliamengo', 3),
#  ('horrible', 3),
#  ("Don't", 3),
#  ('call', 3),
#  ('beaner', 3),
#  ('puñetero', 3),
#  ('abrir', 3),
#  ('jajajajajaja', 3),
#  ('sudaka', 3),
#  ('página', 3),
#  ('enseñaré', 3),
#  ('vi', 3),
#  ('favorita', 3),
#  ('delincuente', 3),
#  ('corrupta', 3),
#  ('llamada', 3),
#  ('asqueroso', 3),
#  ('inteligencia', 3),
#  ('personalidad', 3),
#  ('Espana', 3),
#  ('presidente', 3),
#  ('migrantes', 3),
#  ('recibir', 3),
#  ('tí', 3),
#  ('Estás', 3),
#  ('patética', 3),
#  ('tesis', 3),
#  ('10', 3),
#  ('cabron', 3),
#  ('extrañas', 3),
#  ('merece', 3),
#  ('salir', 3),
#  ('nacional', 3),
#  ('dejar', 3),
#  ('calor', 3),
#  ('serio', 3),
#  ('pongo', 3),
#  ('Gobierno', 3),
#  ('noticias', 3),
#  ('encanta', 3),
#  ('ojos', 3),
#  ('doble', 3),
#  ('Alemania', 3),
#  ('Baby', 3),
#  ('tenías', 3),
#  ('fronteras', 3),
#  ('ahre', 3),
#  ('rápido', 3),
#  ('Lástima', 3),
#  ('AMIGA', 3),
#  ('oficial', 3),
#  ('PUTOS', 3),
#  ('culiao', 3),
#  ('nomas', 3),
#  ('insultando', 3),
#  ('judíos', 3),
#  ('creen', 3),
#  ('raza', 3),
#  ('buscar', 3),
#  ('gentuza', 3),
#  ('@guardiacivil', 3),
#  ('MILES', 3),
#  ('MOROS', 3),
#  ('jefe', 3),
#  ('JAJAJAJAJAJAJAJA', 3),
#  ('traidor', 3),
#  ('@sebastianpinera', 3),
#  ('puesto', 3),
#  ('paguita', 3),
#  ('gratis', 3),
#  ('cabello', 3),
#  ('maduro', 3),
#  ('jajajajaj', 3),
#  ('saltado', 3),
#  ('cama', 3),
#  ('cubanos', 3),
#  ('ataques', 3),
#  ('Seguro', 3),
#  ('ángel', 3),
#  ('prensa', 3),
#  ('saltando', 3),
#  ('cabe', 3),
#  ('HDP', 3),
#  ('patada', 3),
#  ('divina', 3),
#  ('coche', 3),
#  ('quedar', 3),
#  ('salido', 3),
#  ('llorando', 3),
#  ('tia', 3),
#  ('marroquí', 3),
#  ('YEGUA', 3),
#  ('cesants', 3),
#  ('aumento', 3),
#  ('laboral', 3),
#  ('nación', 3),
#  ('UE', 3),
#  ('empieza', 3),
#  ('decis', 3),
#  ('falda', 3),
#  ('vecinos', 3),
#  ('ves', 3),
#  ('ojala', 3),
#  ('Sudacas', 3),
#  ('PARIDA', 3),
#  ('quitan', 3),
#  ('20', 3),
#  ('cola', 3),
#  ('Grande', 3),
#  ('Marlaska', 3),
#  ('inmediatamente', 3),
#  ('hijas', 3),
#  ('señora', 3),
#  ('Arabe', 3),
#  ('40.000', 3),
#  ('suerte', 3),
#  ('libro', 3),
#  ('sindicato', 3),
#  ('twitter', 3),
#  ('pilla', 3),
#  ('fama', 3),
#  ('dedos', 3),
#  ('piden', 3),
#  ('mentira', 3),
#  ('etc.', 3),
#  ('vende', 3),
#  ('forma', 3),
#  ('terrorista', 3),
#  ('fácil', 3),
#  ('mañana', 3),
#  ('oh', 3),
#  ('PUTO', 3),
#  ('regalo', 3),
#  ('pones', 3),
#  ('sabia', 3),
#  ('pinché', 3),
#  ('feminista', 3),
#  ('justicia', 3),
#  ('banco', 3),
#  ('podrido', 3),
#  ('necesita', 3),
#  ('jamás', 3),
#  ('presa', 3),
#  ('ponen', 3),
#  ('Indocumentados', 3),
#  ('pide', 3),
#  ('Mereces', 3),
#  ('seguir', 3),
#  ('pollas', 3),
#  ('sueldos', 3),
#  ('mitad', 3),
#  ('cretino', 3),
#  ('par', 3),
#  ('MIRA', 3),
#  ('campaña', 3),
#  ('condena', 3),
#  ('idiota', 3),
#  ('perdón', 3),
#  ('puertas', 3),
#  ('agrede', 3),
#  ('políticos', 3),
#  ('CRISIS', 3),
#  ('HUMANITARIA', 3),
#  ('trola', 3),
#  ('hijueputa', 3),
#  ('Ah', 3),
#  ('canta', 3),
#  ('completo', 3),
#  ('traidora', 3),
#  ('espera', 3),
#  ('nombre', 3),
#  ('EEUU', 3),
#  ('VALLA', 3),
#  ('plata', 3),
#  ('déjame', 3),
#  ('@AdaColau', 3),
#  ('obra', 3),
#  ('Israel', 3),
#  ('Siria', 3),
#  ('costas', 3),
#  ('ley', 3),
#  ('Maldita', 3),
#  ('izquierda', 3),
#  ('miau', 3),
#  ('tw', 3),
#  ('PUTAS', 3),
#  ('Puto', 3),
#  ('economía', 3),
#  ('asalto', 3),
#  ('gallina', 2),
#  ('quieras', 2),
#  ('sudakas', 2),
#  ('miserables', 2),
#  ('sorete', 2),
#  ('Vienen', 2),
#  ('atrás', 2),
#  ('Querida', 2),
#  ('fregar', 2),
#  ('congreso', 2),
#  ('primaria', 2),
#  ('santa', 2),
#  ('cuarta', 2),
#  ('ExatlonMx', 2),
#  ('nacos', 2),
#  ('pensiones', 2),
#  ('NosTomanPorImbéciles', 2),
#  ('https://t.co/2pR0YPtNCA', 2),
#  ('@ash_london', 2),
#  ('ganado', 2),
#  ('piensa', 2),
#  ('Instagram', 2),
#  ('Sevilla', 2),
#  ('económicos', 2),
#  ('mentiras', 2),
#  ('convivir', 2),
#  ('asilados', 2),
#  ('zona', 2),
#  ('policía', 2),
#  ('niñas', 2),
#  ('via', 2),
#  ('SUDACA', 2),
#  ('natal', 2),
#  ('estáis', 2),
#  ('normas', 2),
#  ('poniendo', 2),
#  ('pies', 2),
#  ('Negros', 2),
#  ('@ahorapodemos', 2),
#  ('puedan', 2),
#  ('@ManuelaCarmena', 2),
#  ('PASA', 2),
#  ('HIJOS', 2),
#  ('CERDA', 2),
#  ('paliza', 2),
#  ('deportado', 2),
#  ('Cartagena', 2),
#  ('gobernantes', 2),
#  ('extremistas', 2),
#  ('clava', 2),
#  ('metro', 2),
#  ('resultado', 2),
#  ('ciudadano', 2),
#  ('cero', 2),
#  ('cristianos', 2),
#  ('2017', 2),
#  ('11', 2),
#  ('Gómez', 2),
#  ('cargó', 2),
#  ('Deja', 2),
#  ('provocarme', 2),
#  ('bebé', 2),
#  ('enseñarme', 2),
#  ('Mierda', 2),
#  ('África', 2),
#  ('africana', 2),
#  ('jajaj', 2),
#  ('animales', 2),
#  ('solucionar', 2),
#  ('@elmundoes', 2),
#  ('@BreenDLP', 2),
#  ('@ChumelTorres', 2),
#  ('acabo', 2),
#  ('escuchar', 2),
#  ('my', 2),
#  ('bailar', 2),
#  ('requiere', 2),
#  ('españa', 2),
#  ('pueblos', 2),
#  ('Dcho', 2),
#  ('LIBREDETERMINACIÓN', 2),
#  ('tb', 2),
#  ('tanta', 2),
#  ('algun', 2),
#  ('esposa', 2),
#  ('cocina', 2),
#  ('vino', 2),
#  ('resentidos', 2),
#  ('ala', 2),
#  ('PD', 2),
#  ('quedas', 2),
#  ('@infobae', 2),
#  ('CHORRA', 2),
#  ('PATRIA', 2),
#  ('suficientes', 2),
#  ('di', 2),
#  ('encuentras', 2),
#  ('pego', 2),
#  ('pene', 2),
#  ('abajo', 2),
#  ('seguridad', 2),
#  ('becas', 2),
#  ('competencia', 2),
#  ('queja', 2),
#  ('suba', 2),
#  ('@LIGABancomerMX', 2),
#  ('simio', 2),
#  ('dandoles', 2),
#  ('hayan', 2),
#  ('dejamos', 2),
#  ('diario', 2),
#  ('JODER', 2),
#  ('idea', 2),
#  ('cambio', 2),
#  ('LIBRE', 2),
#  ('not', 2),
#  ('boba', 2),
#  ('animal', 2),
#  ('piense', 2),
#  ('madurez', 2),
#  ('enojado', 2),
#  ('patio', 2),
#  ('saca', 2),
#  ('soldado', 2),
#  ('Sanidad', 2),
#  ('promoción', 2),
#  ('realidad', 2),
#  ('CUERPO', 2),
#  ('Muérete', 2),
#  ('Alarma', 2),
#  ('50.000', 2),
#  ('tomar', 2),
#  ('ARABES', 2),
#  ('sirve', 2),
#  ('radical', 2),
#  ('islam', 2),
#  ('escuelas', 2),
#  ('FOTO', 2),
#  ('PA', 2),
#  ('GENTE', 2),
#  ('Wey', 2),
#  ('enchufado', 2),
#  ('academia', 2),
#  ('gorrilla', 2),
#  ('FEMINISTA', 2),
#  ('juro', 2),
#  ('100%', 2),
#  ('Maduro', 2),
#  ('manadas', 2),
#  ('débiles', 2),
#  ('Amparo', 2),
#  ('pq', 2),
#  ('aprende', 2),
#  ('inmigracion', 2),
#  ('legal', 2),
#  ('toman', 2),
#  ('Espero', 2),
#  ('mejores', 2),
#  ('risa', 2),
#  ('putear', 2),
#  ('Canarias', 2),
#  ('vendiendo', 2),
#  ('pequeños', 2),
#  ('viola', 2),
#  ('medias', 2),
#  ('echo', 2),
#  ('dientes', 2),
#  ('fuego', 2),
#  ('@danielanatt', 2),
#  ('aparte', 2),
#  ('AMOR', 2),
#  ('PEAZO', 2),
#  ('contestar', 2),
#  ('educación', 2),
#  ('tratan', 2),
#  ('vengan', 2),
#  ('maricas', 2),
#  ('armario', 2),
#  ('bailas', 2),
#  ('anoche', 2),
#  ('saltan', 2),
#  ('queréis', 2),
#  ('fuerzas', 2),
#  ('lindo', 2),
#  ('argentina', 2),
#  ('arrimadas', 2),
#  ('vídeos', 2),
#  ('defienden', 2),
#  ('pavo', 2),
#  ('montonera', 2),
#  ('cargo', 2),
#  ('diputada', 2),
#  ('pagas', 2),
#  ('cool', 2),
#  ('ladrones', 2),
#  ('cliente', 2),
#  ('vagos', 2),
#  ('resto', 2),
#  ('feos', 2),
#  ('Alguien', 2),
#  ('absorber', 2),
#  ('Subsaharianos', 2),
#  ('Casado', 2),
#  ('conoces', 2),
#  ('quería', 2),
#  ('EUROPA', 2),
#  ('salen', 2),
#  ('vallas', 2),
#  ('decenas', 2),
#  ('pateras', 2),
#  ('mando', 2),
#  ('hice', 2),
#  ('You', 2),
#  ('digas', 2),
#  ('culero', 2),
#  ('llames', 2),
#  ('frijolero', 2),
#  ('VIEJA', 2),
#  ('pajera', 2),
#  ('llegado', 2),
#  ('doblaje', 2),
#  ('latino', 2),
#  ('Miles', 2),
#  ('droga', 2),
#  ('paguitas', 2),
#  ('iglesia', 2),
#  ('Santa', 2),
#  ('inmunda', 2),
#  ('puerca', 2),
#  ('guapa', 2),
#  ('público', 2),
#  ('calidad', 2),
#  ('pos', 2),
#  ('top', 2),
#  ('costará', 2),
#  ('euros', 2),
#  ('@davidpepi00', 2),
#  ('atravesada', 2),
#  ...]

# %% [markdown]
# #### 1.3 Word Frequecy for Examples that are Hate Speech but not Aggressive

# %%
freqs = slice_dataframe_and_compute_word_frequency(df, ['HS', 'AG'], [1, 0], 'text', 'es_core_news_sm')
freqs.most_common()[:10]
# Out:
# Found a total of 355 examples
# [('mujer', 54),
#  ('inmigrantes', 36),
#  ('mujeres', 32),
#  ('subsaharianos', 23),
#  ('perra', 23),
#  ('puta', 20),
#  ('España', 17),
#  ('país', 17),
#  ('papeles', 16),
#  ('inmigrante', 15),
#  ('indocumentados', 14),
#  ('árabes', 13),
#  ('hombre', 13),
#  ('valla', 12),
#  ('gente', 12),
#  ('hombres', 11),
#  ('manteros', 11),
#  ('sudaca', 11),
#  ('inmigración', 10),
#  ('ilegales', 10),
#  ('acoso', 10),
#  ('sudacas', 10),
#  ('casa', 10),
#  ('Ceuta', 9),
#  ('años', 9),
#  ('zorra', 9),
#  ('vienen', 8),
#  ('árabe', 8),
#  ('españoles', 8),
#  ('guarra', 8),
#  ('mundo', 8),
#  ('ilegal', 7),
#  ('amor', 7),
#  ('dinero', 7),
#  ('negros', 7),
#  ('refugiados', 7),
#  ('quieren', 7),
#  ('vida', 7),
#  ('invasión', 7),
#  ('cultura', 7),
#  ('cabeza', 6),
#  ('Marruecos', 6),
#  ('tienes', 6),
#  ('Europa', 6),
#  ('Barcelona', 6),
#  ('unga', 6),
#  ('xq', 6),
#  ('venir', 5),
#  ('-Porque', 5),
#  ('güera', 5),
#  ('visto', 5),
#  ('guerra', 5),
#  ('vacaciones', 5),
#  ('turistas', 5),
#  ('tetas', 5),
#  ('vía', 5),
#  ('personas', 5),
#  ('culo', 5),
#  ('tipo', 5),
#  ('venezolanos', 5),
#  ('arabes', 5),
#  ('viene', 5),
#  ('control', 4),
#  ('cara', 4),
#  ('calle', 4),
#  ('Gracias', 4),
#  ('güero', 4),
#  ('creen', 4),
#  ('diciendo', 4),
#  ('agresión', 4),
#  ('INMIGRANTES', 4),
#  ('presidente', 4),
#  ('indocumentado', 4),
#  ('joven', 4),
#  ('falta', 4),
#  ('sexual', 4),
#  ('moros', 4),
#  ('ayudas', 4),
#  ('güeros', 4),
#  ('parecen', 4),
#  ('gracias', 4),
#  ('pasa', 4),
#  ('arabe', 4),
#  ('gusta', 4),
#  ('  ', 4),
#  ('polla', 4),
#  ('coño', 4),
#  ('pueblo', 4),
#  ('dando', 4),
#  ('calles', 4),
#  ('viven', 4),
#  ('doble', 4),
#  ('derechos', 4),
#  ('hijos', 4),
#  ('Melilla', 4),
#  ('enseñar', 4),
#  ('chiste', 4),
#  ('vivir', 4),
#  ('avión', 3),
#  ('gobierno', 3),
#  ('año', 3),
#  ('inteligentes', 3),
#  ('cambio', 3),
#  ('razón', 3),
#  ('pase', 3),
#  ('subsahariano', 3),
#  ('ven', 3),
#  ('pasó', 3),
#  ('Pregunta', 3),
#  ('inteligente', 3),
#  ('señor', 3),
#  ('negra', 3),
#  ('esperan', 3),
#  ('entrar', 3),
#  ('ilegalmente', 3),
#  ('Moncloa', 3),
#  ('llevan', 3),
#  ('nigeriano', 3),
#  ('Milán', 3),
#  ('realidad', 3),
#  ('español', 3),
#  ('estén', 3),
#  ('Mujer', 3),
#  ('entrada', 3),
#  ('problemas', 3),
#  ('metro', 3),
#  ('sociales', 3),
#  ('fregar', 3),
#  ('putas', 3),
#  ('juego', 3),
#  ('negro', 3),
#  ('digo', 3),
#  ('machismo', 3),
#  ('escote', 3),
#  ('Colau', 3),
#  ('20', 3),
#  ('pasan', 3),
#  ('comercios', 3),
#  ('marroquíes', 3),
#  ('digan', 3),
#  ('negratas', 3),
#  ('origen', 3),
#  ('INMIGRACION', 3),
#  ('ILEGAL', 3),
#  ('ESPAÑA', 3),
#  ('pasta', 3),
#  ('mantero', 3),
#  ('enseñando', 3),
#  ('partido', 3),
#  ('llamada', 3),
#  ('expulsar', 3),
#  ('racista', 3),
#  ('mitad', 3),
#  ('africanos', 3),
#  ('menores', 3),
#  ('animales', 3),
#  ('extranjeros', 3),
#  ('llenar', 3),
#  ('sanidad', 3),
#  ('quejan', 3),
#  ('fotos', 3),
#  ('habría', 3),
#  ('autoridades', 3),
#  ('chica', 3),
#  ('favor', 3),
#  ('Guarra', 3),
#  ('has', 3),
#  ('pregunta', 3),
#  ('meses', 3),
#  ('frontera', 3),
#  ('Turismo', 3),
#  ('jóvenes', 3),
#  ('chinos', 3),
#  ('quiero', 3),
#  ('sos', 3),
#  ('sistema', 3),
#  ('impuestos', 3),
#  ('Pedro', 3),
#  ('cerebro', 3),
#  ('-¿Por', 3),
#  ('hubiera', 3),
#  ('lista', 3),
#  ('hau', 3),
#  ('D_Nacional', 3),
#  ('Colombia', 2),
#  ('amigos', 2),
#  ('hablando', 2),
#  ('-Nada', 2),
#  ('dejar', 2),
#  ('sueltos', 2),
#  ('ciudades', 2),
#  ('pagar', 2),
#  ('-¿Porque', 2),
#  ('mujers', 2),
#  ('sexo', 2),
#  ('violenta', 2),
#  ('peleas', 2),
#  ('@pablocasado', 2),
#  ('costumbres', 2),
#  ('atención', 2),
#  ('racismo', 2),
#  ('explicar', 2),
#  ('victimas', 2),
#  ('mirada', 2),
#  ('ridículas', 2),
#  ('chico', 2),
#  ('madre', 2),
#  ('denuncias', 2),
#  ('violencia', 2),
#  ('puso', 2),
#  ('izquierda', 2),
#  ('tortuga', 2),
#  ('vieja', 2),
#  ('Sanchez', 2),
#  ('medidas', 2),
#  ('etc.', 2),
#  ('debería', 2),
#  ('acoger', 2),
#  ('ordenada', 2),
#  ('labios', 2),
#  ('marcha', 2),
#  ('acelera', 2),
#  ('paso', 2),
#  ('40.000', 2),
#  ('comprado', 2),
#  ('Africa', 2),
#  ('18', 2),
#  ('ATENCION', 2),
#  ('limpiar', 2),
#  ('cocina', 2),
#  ('cosa', 2),
#  ('españaesuna', 2),
#  ('stopUE', 2),
#  ('stopLGTB', 2),
#  ('coche', 2),
#  ('tonterias', 2),
#  ('abajo', 2),
#  ('Italia', 2),
#  ('estación', 2),
#  ('andan', 2),
#  ('violaciones', 2),
#  ('cría', 2),
#  ('comen', 2),
#  ('Venezuela', 2),
#  ('Quiero', 2),
#  ('pobres', 2),
#  ('solución', 2),
#  ('15', 2),
#  ('siembran', 2),
#  ('Racismo', 2),
#  ('Dios', 2),
#  ('servicios', 2),
#  ('SEMEN', 2),
#  ('mereces', 2),
#  ('llamar', 2),
#  ('feminazis', 2),
#  ('SUDACA', 2),
#  ('putos', 2),
#  ('racistas', 2),
#  ('montón', 2),
#  ('inferiores', 2),
#  ('Reverte', 2),
#  ('lesbiana', 2),
#  ('asco', 2),
#  ('gratis', 2),
#  ('tanta', 2),
#  ('Ada', 2),
#  ('acogida', 2),
#  ('lucha', 2),
#  ('Túnez', 2),
#  ('mayoría', 2),
#  ('Sanidad', 2),
#  ('cobrando', 2),
#  ('requisitos', 2),
#  ('blanco', 2),
#  ('lavadora', 2),
#  ('moromierdas', 2),
#  ('cientifico', 2),
#  ('importa', 2),
#  ('-Machista', 2),
#  ('musulmana', 2),
#  ('adaptarse', 2),
#  ('@ahorapodemos', 2),
#  ('vengan', 2),
#  ('legales', 2),
#  ('vendiendo', 2),
#  ('niños', 2),
#  ('pueblos', 2),
#  ('encabrona', 2),
#  ('encanta', 2),
#  ('desgarro', 2),
#  ('vaginal', 2),
#  ('note', 2),
#  ('puto', 2),
#  ('inmigracion', 2),
#  ('paises', 2),
#  ('baño', 2),
#  ('merecía', 2),
#  ('salió', 2),
#  ('mala', 2),
#  ('esperar', 2),
#  ('StopInvasion', 2),
#  ('ji', 2),
#  ('ja', 2),
#  ('nacionalidad', 2),
#  ('crees', 2),
#  ('europea', 2),
#  ('tema', 2),
#  ('Español', 2),
#  ('sociedad', 2),
#  ('entrado', 2),
#  ('legal', 2),
#  ('entran', 2),
#  ('ciudadanos', 2),
#  ('NEGROS', 2),
#  ('cuesta', 2),
#  ('busca', 2),
#  ('civilización', 2),
#  ('totalmente', 2),
#  ('enemigo', 2),
#  ('enseño', 2),
#  ('defenderse', 2),
#  ('rica', 2),
#  ('ojos', 2),
#  ('elecciones', 2),
#  ('países', 2),
#  ('miles', 2),
#  ('Madrid', 2),
#  ('novia', 2),
#  ('africana', 2),
#  ('cuento', 2),
#  ('Asia', 2),
#  ('100.000', 2),
#  ('derecho', 2),
#  ('voto', 2),
#  ('grabado', 2),
#  ('señoras', 2),
#  ('mirado', 2),
#  ('pasar', 2),
#  ('vino', 2),
#  ('pide', 2),
#  ('calor', 2),
#  ('seguridad', 2),
#  ('25', 2),
#  ('lógico', 2),
#  ('quiera', 2),
#  ('10', 2),
#  ('Arabes', 2),
#  ('dedicado', 2),
#  ('ciudad', 2),
#  ('sur', 2),
#  ('robar', 2),
#  ('Panamá', 2),
#  ('fútbol', 2),
#  ('cuchillo', 2),
#  ('tristes', 2),
#  ('único', 2),
#  ('deporte', 2),
#  ('Camerún', 2),
#  ('violar', 2),
#  ('lento', 2),
#  ('piensan', 2),
#  ('aeropuertos', 2),
#  ('2018', 2),
#  ('Ay', 2),
#  ('amiga', 2),
#  ('Carmena', 2),
#  ('asaltar', 2),
#  ('violentos', 2),
#  ('problema', 2),
#  ('políticos', 2),
#  ('@realDonaldTrump', 2),
#  ('inteligencia', 2),
#  ('Rambla', 2),
#  ('puro', 2),
#  ('tantos', 2),
#  ('Perú', 2),
#  ('niña', 2),
#  ('tonterías', 2),
#  ('esperando', 2),
#  ('Sánchez', 2),
#  ('vaca', 2),
#  ('ropa', 2),
#  ('modelos', 2),
#  ('machista', 2),
#  ('turcos', 2),
#  ('ley', 2),
#  ('sangre', 2),
#  ('telefono', 2),
#  ('desempleo', 2),
#  ('quitan', 2),
#  ('-En', 2),
#  ('EUROPA', 2),
#  ('DESTRUIR', 2),
#  ('jodidos', 2),
#  ('buscando', 2),
#  ('Alcaldesa', 2),
#  ('cae', 2),
#  ('historia', 2),
#  ('tercer', 2),
#  ('falda', 2),
#  ('secreto', 2),
#  ('violador', 2),
#  ('pedir', 2),
#  ('viejas', 2),
#  ('ganar', 2),
#  ('violacion', 2),
#  ('comercial', 2),
#  ('tiro', 2),
#  ('dejas', 2),
#  ('saltan', 2),
#  ('sacan', 2),
#  ('mafia', 2),
#  ('permiten', 2),
#  ('envía', 2),
#  ('musulmanes', 2),
#  ('malditos', 2),
#  ('pie', 2),
#  ('hora', 2),
#  ('muertos', 2),
#  ('recuerde', 2),
#  ('ponen', 2),
#  ('siguen', 2),
#  ('casado', 2),
#  ('millones', 2),
#  ('mencionas', 2),
#  ('Árabes', 2),
#  ('animal', 2),
#  ('pagan', 2),
#  ('pegan', 2),
#  ('simplemente', 2),
#  ('invasion', 2),
#  ('veo', 2),
#  ('fuertes', 2),
#  ('dispuestos', 2),
#  ('Unidos', 2),
#  ('femenino', 2),
#  ('cargo', 2),
#  ('casan', 2),
#  ('Humor', 2),
#  ('turismo', 2),
#  ('agredido', 2),
#  ('socialismo', 2),
#  ('par', 2),
#  ('Reconquista', 2),
#  ('religión', 2),
#  ('Sudacas', 2),
#  ('Mexicanos', 2),
#  ('pongan', 2),
#  ('proletarios', 2),
#  ('siesta', 2),
#  ('platos', 2),
#  ('Easyjet', 1),
#  ('duplicar', 1),
#  ('número', 1),
#  ('piloto', 1),
#  ('Verás', 1),
#  ('aparcar', 1),
#  ('http://t.co/46NuLkm09x', 1),
#  ('crear', 1),
#  ('estricto', 1),
#  ('zonas', 1),
#  ('fronterizas', 1),
#  ('20-8querrán', 1),
#  ('masa', 1),
#  ('-Raúl', 1),
#  ('das', 1),
#  ('-Trato', 1),
#  ('paga', 1),
#  ('factura', 1),
#  ('reparten', 1),
#  ('marrón', 1),
#  ('votantes', 1),
#  ('hagan', 1),
#  ('https://t.co/CehRdJsSdU', 1),
#  ('esatua', 1),
#  ('libertad', 1),
#  ('nescesitaba', 1),
#  ('hueca', 1),
#  ('mirador', 1),
#  ('inventó', 1),
#  ('alcohol', 1),
#  ('feas', 1),
#  ('gordas', 1),
#  ('canis', 1),
#  ('perdieran', 1),
#  ('virginidad', 1),
#  ('operado', 1),
#  ('revés', 1),
#  ('muestran', 1),
#  ('plena', 1),
#  ('Pueblo', 1),
#  ('https://t.co/Xd26df3yhL', 1),
#  ('-Mujer', 1),
#  ('Bésame', 1),
#  ('pertenecere', 1),
#  ('-Hombre', 1),
#  ('Ostia', 1),
#  ('advertencia', 1),
#  ('@Albert_Rivera', 1),
#  ('imponernos', 1),
#  ('https://t.co/xstEpiBjQl', 1),
#  ('-¿Aquí', 1),
#  ('oficina', 1),
#  ('-Claro', 1),
#  ('pásele', 1),
#  ('pinche', 1),
#  ('indio', 1),
#  ('prieto', 1),
#  ('sarrapastrozo', 1),
#  ('ahorita', 1),
#  ('atendemos', 1),
#  ('brutismo', 1),
#  ('caribeño', 1),
#  ('correlación', 1),
#  ('Extreme', 1),
#  ('heat', 1),
#  ('linked', 1),
#  ('with', 1),
#  ('reduced', 1),
#  ('cognitive', 1),
#  ('performance', 1),
#  ('among', 1),
#  ('young', 1),
#  ('adults', 1),
#  ('in', 1),
#  ('non-air-conditioned', 1),
#  ('buildings', 1),
#  ('https://t.co/hRcb6n7jHQ', 1),
#  ('peliculas', 1),
#  ('porno', 1),
#  ('enteras', 1),
#  ('casar', 1),
#  ('@ClaMoralesM', 1),
#  ('confundamos', 1),
#  ('posan', 1),
#  ('habrán', 1),
#  ('comparado', 1),
#  ('sufrieron', 1),
#  ('guerrilleras', 1),
#  ('Farc', 1),
#  ('Negros', 1),
#  ('sepa', 1),
#  ('Sudán', 1),
#  ('Níger', 1),
#  ('Sáhara', 1),
#  ('FronterasSeguras', 1),
#  ('FLIPANDO', 1),
#  ('padre', 1),
#  ('pegaba', 1),
#  ('insultaba', 1),
#  ('género', 1),
#  ('órdenes', 1),
#  ('alejamiento', 1),
#  ('decirme', 1),
#  ('jamás', 1),
#  ('pensaría', 1),
#  ('https://t.co/JERLbuZynK', 1),
#  ('nota', 1),
#  ('abrimos', 1),
#  ('fronteras', 1),
#  ('indiscriminadamente', 1),
#  ('agrede', 1),
#  ('relación', 1),
#  ('sentimental', 1),
#  ('localiza', 1),
#  ('citarle', 1),
#  ('juicio', 1),
#  ('cuza', 1),
#  ('hermana', 1),
#  ('@unpentagono', 1),
#  ('@medicenlore', 1),
#  ('https://t.co/9iHeSpHOIi', 1),
#  ('cobertura', 1),
#  ('enseñanza', 1),
#  ('bajada', 1),
#  ('tiempopara', 1),
#  ('nacionalizarse', 1),
#  ('mirar', 1),
#  ('agresivos', 1),
#  ('asaltaron', 1),
#  ('lanza-Llamas', 1),
#  ('cal', 1),
#  ('viva', 1),
#  ('https://t.co/RQV4c6TkIQ', 1),
#  ('REFUGIADOS', 1),
#  ('NECESARIOS', 1),
#  ('REALMENTE', 1),
#  ('PODAMOS', 1),
#  ('ATENDER', 1),
#  ('pienso', 1),
#  ('forma', 1),
#  ('latinoamericanos', 1),
#  ('española', 1),
#  ('cristianos', 1),
#  ('https://t.co/mo1PM2oR2l', 1),
#  ('@Victor_EstradaG', 1),
#  ('robaron', 1),
#  ('tapones', 1),
#  ('auto', 1),
#  ('afueras', 1),
#  ('suburbano', 1),
#  ('lechería', 1),
#  ('Llegué', 1),
#  ('9:30', 1),
#  ('pm', 1),
#  ('combis', 1),
#  ('prominentes', 1),
#  ('roba', 1),
#  ('autopartes', 1),
#  ('patrullas', 1),
#  ('tocó', 1),
#  ('https://t.co/0MHGJNwJoz', 1),
#  ('Okupa', 1),
#  ('Monclovita,', 1),
#  ('¿Ya', 1),
#  ('pensado', 1),
#  ('cobijar', 1),
#  ('?Prepara', 1),
#  ('barracas', 1),
#  ('terreno', 1),
#  ('-Le', 1),
#  ('collar', 1),
#  ('esposa', 1),
#  ('Coño', 1),
#  ('suelta', 1),
#  ('ONU', 1),
#  ('UNION', 1),
#  ('EUROPEA', 1),
#  ('VATICANO', 1),
#  ('COMUNISTAS', 1),
#  ('SOCIALISTAS', 1),
#  ('PROGRES', 1),
#  ('NWO', 1),
#  ('mata', 1),
#  ('descuartiza', 1),
#  ('italiana', 1),
#  ('https://t.co/EaxYjwSsLt', 1),
#  ('InformateEnHolaChile', 1),
#  ('RESEPONSABLES', 1),
#  ('INGRESO', 1),
#  ('TANTOS', 1),
#  ('HACERSE', 1),
#  ('CARGO', 1),
#  ('PROBLEMAS', 1),
#  ('SALUD', 1),
#  ('VENIDO', 1),
#  ('AUMENTAR', 1),
#  ('GRAVE', 1),
#  ('PROBLEMA', 1),
#  ('MEDICA', 1),
#  ('CHILENOS', 1),
#  ('OCUPANDO', 1),
#  ('RECURSOS', 1),
#  ('operarios', 1),
#  ('CállateYfriega', 1),
#  ('hostales', 1),
#  ('pensión', 1),
#  ('completa', 1),
#  ('durmiendo', 1),
#  ('https://t.co/rMtZA7ods9', 1),
#  ('@CRDecoracion', 1),
#  ('mardita', 1),
#  ('hubiese', 1),
#  ('real', 1),
#  ('nula', 1),
#  ('prestare', 1),
#  ('tarjeta', 1),
#  ('compres', 1),
#  ('personalidad', 1),
#  ('@maricucha568', 1),
#  ('@TRICICLODELPERU', 1),
#  ('@roxcanedo', 1),
#  ('maridos', 1),
#  ('seguro', 1),
#  ('beban', 1),
#  ('cubatas', 1),
#  ('acaba', 1),
#  ('convencer', 1),
#  ('arreglarlas', 1),
#  ('evita', 1),
#  ('gas', 1),
#  ('pimienta', 1),
#  ('tren', 1),
#  ('https://t.co/YybrILTiRk', 1),
#  ('tonta', 1),
#  ('valga', 1),
#  ('redundancia', 1),
#  ('Mierditerráneo', 1),
#  ('Digital', 1),
#  ('obsesionados', 1),
#  ('ficticias', 1),
#  ('Denunciar', 1),
#  ('GC', 1),
#  ('militar', 1),
#  ('violaron', 1),
#  ('queda', 1),
#  ('patriota', 1),
#  ('Gays', 1),
#  ('marroquí', 1),
#  ('gays', 1),
#  ('https://t.co/vyb7wrsJbw', 1),
#  ('huyen', 1),
#  ('huyes', 1),
#  ('vuelves', 1),
#  ('totalidad', 1),
#  ('sirias', 1),
#  ('velo', 1),
#  ('Siria', 1),
#  ('cristiano', 1),
#  ('https://t.co/HzzS2bDlO4', 1),
#  ('descuido', 1),
#  ('https://t.co/p8IiBPxtHd', 1),
#  ('polillas', 1),
#  ('tela', 1),
#  ('EnTuJeta', 1),
#  ('-¿Que', 1),
#  ('perfecta', 1),
#  ('-todo', 1),
#  ('convertir', 1),
#  ('decían', 1),
#  ('semáforos', 1),
#  ('chamo', 1),
#  ('Duque', 1),
#  ('ministerios', 1),
#  ('cancillería', 1),
#  ('chamozolano', 1),
#  ('veais', 1),
#  ('muslims', 1),
#  ('acordaron', 1),
#  ('sangraros', 1),
#  ('subvenciones', 1),
#  ('mayores', 1),
#  ('reciben', 1),
#  ('traves', 1),
#  ('mezquitas', 1),
#  ('locutorios', 1),
#  ('https://t.co/zX6FtMmLbc', 1),
#  ('@santotv4', 1),
#  ('vinieron', 1),
#  ('trabajadores', 1),
#  ('Argentina', 1),
#  ('registrados', 1),
#  ('expusieron', 1),
#  ('Prado', 1),
#  ('agua', 1),
#  ('lados', 1),
#  ('enormes', 1),
#  ('Telediario', 1),
#  ('alemanes', 1),
#  ('pánico', 1),
#  ('Valencia', 1),
#  ('rumanas', 1),
#  ('carteristas', 1),
#  ('agreden', 1),
#  ('juntan', 1),
#  ('https://t.co/502fqNeUBo', 1),
#  ('invadiendo', 1),
#  ('acogiendo', 1),
#  ('regalandoles', 1),
#  ('https://t.co/iRPOROgtwW', 1),
#  ('@TiaFeminazi', 1),
#  ('Movimiento', 1),
#  ('http://t.co/u9WvI5Fr18', 1),
#  ('punterías', 1),
#  ('@sexyany99', 1),
#  ('daria', 1),
#  ('1000', 1),
#  ('encantan', 1),
#  ('@bbcmundo', 1),
#  ('Lamentablemente', 1),
#  ('provocará', 1),
#  ('radicalismo', 1),
#  ('casos', 1),
#  ('reales', 1),
#  ('requerirán', 1),
#  ('intervención', 1),
#  ('penal', 1),
#  ('caigamos', 1),
#  ('Currently', 1),
#  ('reading', 1),
#  ('https://t.co/aBtfL4OvM1', 1),
#  ('VAYAN', 1),
#  ('PERDIENDO', 1),
#  ('MIEDO', 1),
#  ('IRAN', 1),
#  ('DUEÑOS', 1),
#  ('CALLES', 1),
#  ('FORMA', 1),
#  ('VIOLENTA', 1),
#  ('turbante', 1),
#  ('politivida', 1),
#  ('puedes', 1),
#  ('cambiarlo', 1),
#  ('DESTINO', 1),
#  ('https://t.co/2tpPakccSk', 1),
#  ('https://t.co/7csHuuOvzP', 1),
#  ('hebreo', 1),
#  ('farfullan', 1),
#  ('sionistas', 1),
#  ('suena', 1),
#  ('parecido', 1),
#  ('relacionado', 1),
#  ('https://t.co/bdXtFVeDr0', 1),
#  ('Saltan', 1),
#  ('grito', 1),
#  ('video', 1),
#  ('https://t.co/yTZ2ajQb4', 1),
#  ('https://t.co/S6UrsjjuGY', 1),
#  ('aparte', 1),
#  ('jartá', 1),
#  ('leer', 1),
#  ('Buah', 1),
#  ('llegaré', 1),
#  ('chuparme', 1),
#  ('https://t.co/0U8TbtwnZD', 1),
#  ('@FRivero2', 1),
#  ('@diegoalvarezmgl', 1),
#  ('imbéciles', 1),
#  ('estarán', 1),
#  ('jaleando', 1),
#  ('sitio', 1),
#  ('personaje', 1),
#  ('comer', 1),
#  ('70', 1),
#  ('90', 1),
#  ('@suso_linares', 1),
#  ('@Mishaki', 1),
#  ('@Visentico', 1),
#  ('@MrDonZea', 1),
#  ('@earthblues', 1),
#  ('todasputas', 1),
#  ('@CineJavi', 1),
#  ('tendencia', 1),
#  ('buscan', 1),
#  ('excusa', 1),
#  ('enseñarlas', 1),
#  ('tonteria', 1),
#  ('atacan', 1),
#  ('reyertas', 1),
#  ('Raval', 1),
#  ('visitado', 1),
#  ('italiano', 1),
#  ('Riace', 1),
#  ('repoblado', 1),
#  ('casas', 1),
#  ('integración', 1),
#  ('xenofobia', 1),
#  ('quede', 1),
#  ('Indefinidamente', 1),
#  ('traficantes', 1),
#  ('Proactiva', 1),
#  ('Open', 1),
#  ('Arms', 1),
#  ('vueltas', 1),
#  ('Cerdeña', 1),
#  ('87', 1),
#  ('Malta', 1),
#  ('permiso', 1),
#  ('desembarcar', 1),
#  ('desembarque', 1),
#  ('Libia', 1),
#  ('Egipto', 1),
#  ('llena', 1),
#  ('Sobran', 1),
#  ('RacismoEs', 1),
#  ('García', 1),
#  ('anduvieran', 1),
#  ('quedara', 1),
#  ('https://t.co/1mzNmsVfYB', 1),
#  ('abierta', 1),
#  ('paro', 1),
#  ('venia', 1),
#  ('chollo', 1),
#  ('vestidas', 1),
#  ('boda', 1),
#  ('microondas', 1),
#  ('nevera', 1),
#  ('matado', 1),
#  ('Adrien', 1),
#  ('R.I.P.', 1),
#  ('https://t.co/WTJUSDeVwn', 1),
#  ('40', 1),
#  ('ombligo', 1),
#  ('cabezas', 1),
#  ('fingen', 1),
#  ('PFFFFFFFT', 1),
#  ('wish', 1),
#  ('-MACHISTA', 1),
#  ('incluir', 1),
#  ('escuelas', 1),
#  ('asignatura', 1),
#  ('Islam', 1),
#  ('2050', 1),
#  ('empezar', 1),
#  ('@Cassini63376220', 1),
#  ('@progre_el', 1),
#  ('sobra', 1),
#  ('demasiados', 1),
#  ('Subsaharianos', 1),
#  ('tirados', 1),
#  ('perjudicando', 1),
#  ('copias', 1),
#  ('abuelos', 1),
#  ('llenos', 1),
#  ('alago', 1),
#  ('superioridad', 1),
#  ('follaria', 1),
#  ('provocarte', 1),
#  ('provocas', 1),
#  ('follando', 1),
#  ('follas', 1),
#  ('https://t.co/j8U6umdicd', 1),
#  ('https://t.co/XD4UoApwoL', 1),
#  ('viajará', 1),
#  ('Luna', 1),
#  ('follo', 1),
#  ('dudas', 1),
#  ('Andrej', 1),
#  ('Babiš', 1),
#  ('Presidente', 1),
#  ('Gbno', 1),
#  ('Checo', 1),
#  ('rechaza', 1),
#  ('plano', 1),
#  ('subsahariana', 1),
#  ('Chequia', 1),
#  ('tendrian', 1),
#  ('mantenerlos', 1),
#  ('ayude', 1),
#  ('compatibles', 1),
#  ('https://t.co/VDlqDOeNFN', 1),
#  ('caga', 1),
#  ('aprieta', 1),
#  ('salga', 1),
#  ('mierda', 1),
#  ('-El', 1),
#  ('pensado-', 1),
#  ('paginas', 1),
#  ('feministas', 1),
#  ('deberia', 1),
#  ('darles', 1),
#  ('verguenza', 1),
#  ('exponer', 1),
#  ('ideas', 1),
#  ('pies', 1),
#  ('abuela', 1),
#  ('Natacha', 1),
#  ('Jaitt', 1),
#  ('pegue', 1),
#  ('haberle', 1),
#  ('Latorre', 1),
#  ('https://t.co/cMGdAYrkdC', 1),
#  ('PASAR', 1),
#  ('MANTENER', 1),
#  ('EXPULSARLOS', 1),
#  ('turista', 1),
#  ('pone', 1),
#  ('aprieto', 1),
#  ('https://t.co/C7mZWXAl9P', 1),
#  ('@Elperiodico', 1),
#  ('luchado', 1),
#  ('StopIslam', 1),
#  ('Closeborders', 1),
#  ('Openborders', 1),
#  ('https://t.co/MfmBlBK55I', 1),
#  ('@ladivaza', 1),
#  ('DIVAZA', 1),
#  ('PUEDES', 1),
#  ('PERRA', 1),
#  ('chistes', 1),
#  ('bombas', 1),
#  ('toca', 1),
#  ('vuelo', 1),
#  ('@SuperFedePirata', 1),
#  ('@checharlu', 1),
#  ('TodasPutas', 1),
#  ('vuelve', 1),
#  ('poporopo', 1),
#  ('flo', 1),
#  ('@YolandaRuizRCN', 1),
#  ('@elespectador', 1),
#  ('minifaldas', 1),
#  ('escotes', 1),
#  ('descaderados', 1),
#  ('transparencias', 1),
#  ('etc', 1),
#  ('provocarnos', 1),
#  ('etnia', 1),
#  ('adapta', 1),
#  ('occidental', 1),
#  ('libertades', 1),
#  ('lgtb', 1),
#  ('convi', 1),
#  ('Pf', 1),
#  ('Chinos', 1),
#  ('acostumbrades', 1),
#  ('idk', 1),
#  ('https://t.co/YcmdcFwxcg', 1),
#  ('esq', 1),
#  ...]

# %% [markdown]
# #### 2.  Word Frequecy for Examples that are not Hate Speech

# %%
freqs = slice_dataframe_and_compute_word_frequency(df, ['HS'], [0], 'text', 'es_core_news_sm')
freqs.most_common()[:10]
# Out:
# Found a total of 2643 examples
# [('puta', 784),
#  ('hijo', 237),
#  ('acoso', 198),
#  ('madre', 149),
#  ('perra', 142),
#  ('polla', 141),
#  ('PUTA', 139),
#  ('mierda', 117),
#  ('mereces', 112),
#  ('violación', 110),
#  ('escoria', 98),
#  ('inmigrantes', 87),
#  ('árabe', 84),
#  ('boca', 83),
#  ('cállate', 82),
#  ('callate', 76),
#  ('Callate', 73),
#  ('cara', 71),
#  ('Cállate', 70),
#  ('mujer', 70),
#  ('enseñar', 69),
#  ('árabes', 66),
#  ('vida', 65),
#  ('mujeres', 61),
#  ('sexual', 59),
#  ('indocumentados', 59),
#  ('gente', 57),
#  ('hijos', 56),
#  ('inmigración', 54),
#  ('tienes', 52),
#  ('MADRE', 46),
#  ('refugiados', 44),
#  ('merecía', 44),
#  ('coño', 43),
#  ('imbécil', 43),
#  ('quiero', 43),
#  ('valla', 42),
#  ('CALLATE', 42),
#  ('país', 42),
#  ('arabe', 41),
#  ('España', 40),
#  ('guarra', 40),
#  ('idea', 39),
#  ('güero', 38),
#  ('Ceuta', 38),
#  ('hombre', 37),
#  ('  ', 37),
#  ('mundo', 36),
#  ('tonterías', 36),
#  ('zorra', 35),
#  ('HIJO', 35),
#  ('culo', 33),
#  ('Puta', 33),
#  ('güera', 32),
#  ('inmigrante', 31),
#  ('mil', 30),
#  ('vía', 30),
#  ('años', 30),
#  ('Casado', 29),
#  ('casa', 29),
#  ('personas', 28),
#  ('Arabe', 28),
#  ('vos', 27),
#  ('gusta', 27),
#  ('año', 27),
#  ('alguien', 27),
#  ('puto', 27),
#  ('hija', 26),
#  ('sos', 26),
#  ('re', 26),
#  ('persona', 26),
#  ('pasa', 26),
#  ('hora', 25),
#  ('Árabes', 25),
#  ('hablar', 24),
#  ('hombres', 24),
#  ('MERECES', 24),
#  ('Árabe', 24),
#  ('feliz', 23),
#  ('vas', 23),
#  ('tema', 23),
#  ('culpa', 22),
#  ('novia', 22),
#  ('@YouTube', 22),
#  ('calles', 22),
#  ('violacion', 22),
#  ('tipo', 21),
#  ('callada', 21),
#  ('chica', 21),
#  ('Emiratos', 21),
#  ('enseñando', 21),
#  ('2018', 20),
#  ('arabes', 20),
#  ('deja', 20),
#  ('estás', 19),
#  ('gilipollas', 19),
#  ('enseñarle', 19),
#  ('provocar', 19),
#  ('Trump', 19),
#  ('pena', 19),
#  ('veo', 18),
#  ('violencia', 18),
#  ('@Barbijaputa', 18),
#  ('papeles', 18),
#  ('viejo', 18),
#  ('odio', 18),
#  ('perro', 18),
#  ('problema', 18),
#  ('amor', 18),
#  ('Hijo', 18),
#  ('calle', 18),
#  ('CÁLLATE', 18),
#  ('video', 17),
#  ('pa', 17),
#  ('asco', 17),
#  ('digo', 17),
#  ('imbecil', 17),
#  ('pendejo', 17),
#  ('gracias', 17),
#  ('anda', 17),
#  ('Gracias', 17),
#  ('Unidos', 17),
#  ('familia', 17),
#  ('foto', 17),
#  ('migrantes', 17),
#  ('basura', 17),
#  ('Pablo', 16),
#  ('pego', 16),
#  ('indocumentado', 16),
#  ('Güero', 16),
#  ('subsaharianos', 16),
#  ('cabeza', 16),
#  ('diciendo', 16),
#  ('has', 16),
#  ('comemela', 16),
#  ('abuso', 16),
#  ('Güera', 16),
#  ('vídeo', 16),
#  ('Gobierno', 16),
#  ('frente', 16),
#  ('enseñaron', 15),
#  ('grande', 15),
#  ('@anaisbernal', 15),
#  ('amo', 15),
#  ('niños', 15),
#  ('caso', 15),
#  ('dejar', 15),
#  ('RT', 15),
#  ('derechos', 15),
#  ('ganas', 15),
#  ('países', 15),
#  ('pedazo', 15),
#  ('PP', 15),
#  ('respeto', 14),
#  ('mañana', 14),
#  ('SEMEN', 14),
#  ('ahre', 14),
#  ('cojones', 14),
#  ('dios', 14),
#  ('tenes', 14),
#  ('puedes', 14),
#  ('gabacho', 14),
#  ('Ojalá', 14),
#  ('forma', 14),
#  ('hablando', 14),
#  ('casos', 14),
#  ('ojalá', 14),
#  ('Melilla', 14),
#  ('paso', 14),
#  ('@Zurine3', 13),
#  ('jajaja', 13),
#  ('víctimas', 13),
#  ('vale', 13),
#  ('Dios', 13),
#  ('menores', 13),
#  ('mala', 13),
#  ('ilegal', 13),
#  ('llegar', 13),
#  ('único', 13),
#  ('política', 13),
#  ('amigos', 13),
#  ('RE', 13),
#  ('maldito', 13),
#  ('pasar', 13),
#  ('seguro', 13),
#  ('español', 13),
#  ('millones', 13),
#  ('pq', 13),
#  ('concha', 13),
#  ('favor', 13),
#  ('sale', 13),
#  ('Twitter', 13),
#  ('tonto', 13),
#  ('10', 13),
#  ('subnormal', 13),
#  ('gobierno', 13),
#  ('merezca', 12),
#  ('Mira', 12),
#  ('hostia', 12),
#  ('merecia', 12),
#  ('quiera', 12),
#  ('quieren', 12),
#  ('medios', 12),
#  ('historia', 12),
#  ('semana', 12),
#  ('nombre', 12),
#  ('MIERDA', 12),
#  ('visto', 12),
#  ('amigo', 12),
#  ('cuerpo', 12),
#  ('Rivera', 12),
#  ('Comemela', 12),
#  ('morir', 12),
#  ('serio', 12),
#  ('@LeticiaDolera', 12),
#  ('miedo', 12),
#  ('Sánchez', 12),
#  ('mira', 12),
#  ('ojos', 12),
#  ('dinero', 11),
#  ('mejores', 11),
#  ('entiendo', 11),
#  ('fotos', 11),
#  ('tío', 11),
#  ('lindo', 11),
#  ('machismo', 11),
#  ('escuchar', 11),
#  ('entrar', 11),
#  ('ecko', 11),
#  ('denuncia', 11),
#  ('comida', 11),
#  ('paz', 11),
#  ('queda', 11),
#  ('pase', 11),
#  ('hermosa', 11),
#  ('merecéis', 11),
#  ('importa', 11),
#  ('ve', 11),
#  ('empanadas', 11),
#  ('cultura', 11),
#  ('verga', 11),
#  ('fuerte', 11),
#  ('seguir', 10),
#  ('pobre', 10),
#  ('niño', 10),
#  ('joder', 10),
#  ('noche', 10),
#  ('pueblo', 10),
#  ('mano', 10),
#  ('siento', 10),
#  ('garganta', 10),
#  ('sentir', 10),
#  ('pone', 10),
#  ('amiga', 10),
#  ('hermano', 10),
#  ('Joder', 10),
#  ('ay', 10),
#  ('@Relatofeminista', 10),
#  ('súper', 10),
#  ('derecha', 10),
#  ('guerra', 10),
#  ('pinche', 10),
#  ('clase', 10),
#  ('viendo', 10),
#  ('punto', 10),
#  ('acaba', 10),
#  ('partido', 10),
#  ('vergüenza', 10),
#  ('@_eckoyg', 10),
#  ('eh', 10),
#  ('acusaciones', 10),
#  ('Hola', 10),
#  ('canción', 10),
#  ('rompe', 10),
#  ('Cepeda', 10),
#  ('población', 10),
#  ('BOCA', 10),
#  ('@IrantzuVarela', 10),
#  ('equipo', 10),
#  ('quieres', 10),
#  ('parió', 10),
#  ('2017', 9),
#  ('MERECÍA', 9),
#  ('iba', 9),
#  ('cosa', 9),
#  ('Ah', 9),
#  ('atrás', 9),
#  ('ves', 9),
#  ('Venezuela', 9),
#  ('sacar', 9),
#  ('vivir', 9),
#  ('Movimiento', 9),
#  ('palabras', 9),
#  ('pario', 9),
#  ('putas', 9),
#  ('machista', 9),
#  ('acusado', 9),
#  ('vete', 9),
#  ('inventarse', 9),
#  ('MUJER', 9),
#  ('Acoso', 9),
#  ('imbéciles', 9),
#  ('maldita', 9),
#  ('muerte', 9),
#  ('sistema', 9),
#  ('manos', 9),
#  ('políticos', 9),
#  ('mamá', 9),
#  ('ilegales', 9),
#  ('viene', 9),
#  ('dices', 9),
#  ('serie', 9),
#  ('padre', 9),
#  ('gracia', 9),
#  ('güeros', 9),
#  ('merecían', 9),
#  ('encanta', 9),
#  ('Ecko', 9),
#  ('gusto', 8),
#  ('juez', 8),
#  ('digan', 8),
#  ('negro', 8),
#  ('via', 8),
#  ('30', 8),
#  ('venezolanos', 8),
#  ('nena', 8),
#  ('humana', 8),
#  ('super', 8),
#  ('juego', 8),
#  ('ojo', 8),
#  ('señora', 8),
#  ('Espero', 8),
#  ('puerta', 8),
#  ('pegarte', 8),
#  ('salir', 8),
#  ('Guardia', 8),
#  ('Civil', 8),
#  ('malo', 8),
#  ('insulto', 8),
#  ('palabra', 8),
#  ('espero', 8),
#  ('cree', 8),
#  ('papá', 8),
#  ('hermana', 8),
#  ('sudaca', 8),
#  ('ciudad', 8),
#  ('miles', 8),
#  ('orto', 8),
#  ('rata', 8),
#  ('subsahariano', 8),
#  ('Quiero', 8),
#  ('cago', 8),
#  ('huevos', 8),
#  ('razón', 8),
#  ('policía', 8),
#  ('comer', 8),
#  ('situación', 8),
#  ('HIJOS', 8),
#  ('española', 8),
#  ('denuncias', 8),
#  ('MIL', 8),
#  ('tierra', 8),
#  ('chaval', 8),
#  ('calor', 8),
#  ('Europa', 8),
#  ('comentarios', 8),
#  ('ayuda', 8),
#  ('normal', 8),
#  ('dormir', 8),
#  ('duro', 8),
#  ('entender', 8),
#  ('diga', 8),
#  ('sociedad', 8),
#  ('igualdad', 8),
#  ('jajajaja', 8),
#  ('padres', 8),
#  ('campo', 8),
#  ('sexo', 8),
#  ('creer', 8),
#  ('OTGala7', 8),
#  ('estilo', 7),
#  ('presidente', 7),
#  ('gordo', 7),
#  ('to', 7),
#  ('@el_pais', 7),
#  ('subir', 7),
#  ('18', 7),
#  ('justo', 7),
#  ('realidad', 7),
#  ('animal', 7),
#  ('futuro', 7),
#  ('dije', 7),
#  ('ÁRABES', 7),
#  ('tomar', 7),
#  ('voz', 7),
#  ('corazón', 7),
#  ('simple', 7),
#  ('delito', 7),
#  ('lucha', 7),
#  ('asesinato', 7),
#  ('cárcel', 7),
#  ('muerto', 7),
#  ('in', 7),
#  ('tíos', 7),
#  ('habéis', 7),
#  ('meses', 7),
#  ('gana', 7),
#  ('programa', 7),
#  ('loco', 7),
#  ('escuchando', 7),
#  ('Imbécil', 7),
#  ('VOS', 7),
#  ('dando', 7),
#  ('México', 7),
#  ('moral', 7),
#  ('internacional', 7),
#  ('Policía', 7),
#  ('pensar', 7),
#  ('chupa', 7),
#  ('perfil', 7),
#  ('riesgo', 7),
#  ('crea', 7),
#  ('vieja', 7),
#  ('justificar', 7),
#  ('Hijos', 7),
#  ('provocación', 7),
#  ('denuncian', 7),
#  ('feminismo', 7),
#  ('insultar', 7),
#  ('haga', 7),
#  ('esperando', 7),
#  ('DIOS', 7),
#  ('Pedro', 7),
#  ('inmigracion', 7),
#  ('saltar', 7),
#  ('@sanchezcastejon', 7),
#  ('das', 7),
#  ('extraño', 7),
#  ('humanos', 7),
#  ('llamar', 7),
#  ('acogida', 7),
#  ('gustado', 7),
#  ('noticias', 7),
#  ('fútbol', 7),
#  ('libre', 7),
#  ('jefe', 7),
#  ('gabacha', 7),
#  ('iglesia', 7),
#  ('Zorra', 7),
#  ('merece', 7),
#  ('fuerza', 7),
#  ('plan', 7),
#  ('tía', 7),
#  ('jamás', 7),
#  ('PSOE', 7),
#  ('puesto', 7),
#  ('Laiki', 7),
#  ('jaja', 7),
#  ('etc', 7),
#  ('falta', 7),
#  ('laboral', 6),
#  ('callejero', 6),
#  ('debería', 6),
#  ('menor', 6),
#  ('daño', 6),
#  ('regalo', 6),
#  ('seas', 6),
#  ('INMIGRANTES', 6),
#  ('ESCORIA', 6),
#  ('Inmigración', 6),
#  ('meten', 6),
#  ('Coño', 6),
#  ('@elchiringuitotv', 6),
#  ('encuentro', 6),
#  ('POLLA', 6),
#  ('pasando', 6),
#  ('ido', 6),
#  ('pelo', 6),
#  ('leer', 6),
#  ('VIDA', 6),
#  ('PUTO', 6),
#  ('TACOS', 6),
#  ('güeras', 6),
#  ('libro', 6),
#  ('hablas', 6),
#  ('porno', 6),
#  ('chicas', 6),
#  ('desierto', 6),
#  ('religión', 6),
#  ('llorar', 6),
#  ('educación', 6),
#  ('feo', 6),
#  ('mes', 6),
#  ('molesta', 6),
#  ('papichamp', 6),
#  ('videos', 6),
#  ('causa', 6),
#  ('ARABE', 6),
#  ('fuiste', 6),
#  ('mama', 6),
#  ('risa', 6),
#  ('catalanes', 6),
#  ('muertos', 6),
#  ('acabar', 6),
#  ('minutos', 6),
#  ('crisis', 6),
#  ('Aquarius', 6),
#  ('efecto', 6),
#  ('mafias', 6),
#  ('ACOSO', 6),
#  ('pedo', 6),
#  ('pongo', 6),
#  ('esté', 6),
#  ('calladas', 6),
#  ('come', 6),
#  ('quedar', 6),
#  ('San', 6),
#  ('ostia', 6),
#  ('responsable', 6),
#  ('tocar', 6),
#  ('perder', 6),
#  ('mayoría', 6),
#  ('campaña', 6),
#  ('40', 6),
#  ('heridos', 6),
#  ('deberían', 6),
#  ('llegan', 6),
#  ('Arabes', 6),
#  ('parar', 6),
#  ('legal', 6),
#  ('ganar', 6),
#  ('EEUU', 6),
#  ('linda', 6),
#  ('mereceis', 6),
#  ('MERECIA', 6),
#  ('tanta', 6),
#  ('Chile', 6),
#  ('protección', 6),
#  ('Güeros', 6),
#  ('única', 6),
#  ('sábado', 6),
#  ('Marruecos', 6),
#  ('llevan', 6),
#  ('Pinche', 6),
#  ('gil', 6),
#  ('20', 6),
#  ('diferencia', 6),
#  ('cientos', 6),
#  ('hostias', 6),
#  ('suerte', 6),
#  ('pregunta', 6),
#  ('22', 6),
#  ('asunto', 6),
#  ('libertad', 6),
#  ('unico', 6),
#  ('escuelas', 6),
#  ('viven', 6),
#  ('gustan', 6),
#  ('cine', 6),
#  ('debo', 6),
#  ('lunes', 6),
#  ('señor', 6),
#  ('you', 6),
#  ('xq', 6),
#  ('novio', 6),
#  ('OTGala9', 6),
#  ('piensa', 6),
#  ('PERRA', 6),
#  ('conoce', 6),
#  ('vi', 6),
#  ('ÁRABE', 6),
#  ('tenéis', 6),
#  ('Hollywood', 6),
#  ('cm', 6),
#  ('hambre', 5),
#  ('público', 5),
#  ('viejos', 5),
#  ('creen', 5),
#  ('CARA', 5),
#  ('ven', 5),
#  ('par', 5),
#  ('mandan', 5),
#  ('@policia', 5),
#  ('asesinos', 5),
#  ('patera', 5),
#  ('costas', 5),
#  ('Sudaca', 5),
#  ('ponen', 5),
#  ('seres', 5),
#  ('sentido', 5),
#  ('besos', 5),
#  ('viernes', 5),
#  ('12', 5),
#  ('SOS', 5),
#  ('gustaría', 5),
#  ('600', 5),
#  ('pesao', 5),
#  ('pide', 5),
#  ('cuento', 5),
#  ('asesino', 5),
#  ('nazi', 5),
#  ('extranjeros', 5),
#  ('pública', 5),
#  ('lomito', 5),
#  ('busca', 5),
#  ('quieran', 5),
#  ('espera', 5),
#  ('QUIERO', 5),
#  ('racista', 5),
#  ('quería', 5),
#  ('capaz', 5),
#  ('crees', 5),
#  ('viaje', 5),
#  ('cabron', 5),
#  ('<3', 5),
#  ('Israel', 5),
#  ('ayudar', 5),
#  ('orden', 5),
#  ('mando', 5),
#  ('deje', 5),
#  ('derecho', 5),
#  ('club', 5),
#  ('necesidad', 5),
#  ('tengan', 5),
#  ('patria', 5),
#  ('putos', 5),
#  ('Escoria', 5),
#  ('alemanes', 5),
#  ('imagen', 5),
#  ('Refugiados', 5),
#  ('Carlos', 5),
#  ('tengas', 5),
#  ('llama', 5),
#  ('nivel', 5),
#  ('dejes', 5),
#  ('llamada', 5),
#  ('problemas', 5),
#  ('loca', 5),
#  ('caga', 5),
#  ('agosto', 5),
#  ('GENTE', 5),
#  ('tantos', 5),
#  ('sabia', 5),
#  ('meto', 5),
#  ('echo', 5),
#  ('banda', 5),
#  ('invasión', 5),
#  ('cantar', 5),
#  ('ENSEÑAR', 5),
#  ('AÑOS', 5),
#  ('ZORRA', 5),
#  ('salto', 5),
#  ('verano', 5),
#  ('triste', 5),
#  ('mensaje', 5),
#  ('bailando', 5),
#  ('fácil', 5),
#  ('espalda', 5),
#  ('Arabia', 5),
#  ('tonterias', 5),
#  ('Axel', 5),
#  ('@todonoticias', 5),
#  ('Bruselas', 5),
#  ('MUNDO', 5),
#  ('rico', 5),
#  ('ARABES', 5),
#  ('@salvameoficial', 5),
#  ('temazo', 5),
#  ('luz', 5),
#  ('sevillista', 5),
#  ('viva', 5),
#  ('200', 5),
#  ('nota', 5),
#  ('on', 5),
#  ('cobarde', 5),
#  ('racistas', 5),
#  ('querer', 5),
#  ('cabello', 5),
#  ('quiso', 5),
#  ('tweet', 5),
#  ('cargo', 5),
#  ('asegura', 5),
#  ('vacaciones', 5),
#  ('defender', 5),
#  ('hubiera', 5),
#  ('payaso', 5),
#  ('Raoul', 5),
#  ('quedarse', 5),
#  ('opinión', 5),
#  ('16', 5),
#  ('trabajadores', 5),
#  ('canal', 5),
#  ('atención', 5),
#  ('cómplice', 5),
#  ('víctima', 5),
#  ('pelotudo', 5),
#  ('venga', 5),
#  ('hechos', 5),
#  ('HIJA', 5),
#  ('ama', 5),
#  ('dura', 5),
#  ('civiles', 5),
#  ('sangre', 5),
#  ('negros', 5),
#  ('AMO', 5),
#  ('media', 5),
#  ('economía', 5),
#  ('lleno', 5),
#  ('Cataluña', 5),
#  ('preocupa', 5),
#  ('Jajajaja', 5),
#  ('alto', 5),
#  ('camino', 5),
#  ('Perra', 5),
#  ('viste', 5),
#  ('echar', 5),
#  ('clases', 5),
#  ('doble', 5),
#  ('vendido', 5),
#  ('redes', 5),
#  ('fuese', 5),
#  ('LOCO', 5),
#  ('Vos', 5),
#  ('PARIO', 5),
#  ('hubiese', 5),
#  ('ridículas', 5),
#  ('rabia', 5),
#  ('bailar', 5),
#  ('pareja', 5),
#  ('salió', 5),
#  ('traidor', 5),
#  ('frase', 5),
#  ('@JoseAMeadeK', 5),
#  ('género', 5),
#  ('Ana', 5),
#  ('buscando', 5),
#  ('toque', 5),
#  ('muertes', 5),
#  ('17', 5),
#  ('idiota', 5),
#  ('edad', 5),
#  ('pateras', 5),
#  ('hiciste', 5),
#  ('Marítimo', 5),
#  ('visita', 5),
#  ('votar', 5),
#  ('efectos', 5),
#  ('Sos', 5),
#  ('mar', 5),
#  ('show', 4),
#  ('máster', 4),
#  ('patada', 4),
#  ('Detienen', 4),
#  ('piensan', 4),
#  ('delincuentes', 4),
#  ('cita', 4),
#  ('jugadores', 4),
#  ('Arandina', 4),
#  ('ofrece', 4),
#  ('difícil', 4),
#  ('jajajajaja', 4),
#  ('violar', 4),
#  ('OTGala8', 4),
#  ('criticar', 4),
#  ('masiva', 4),
#  ('llegado', 4),
#  ('alemán', 4),
#  ('@As_TomasRoncero', 4),
#  ('recorrido', 4),
#  ('pecho', 4),
#  ('sientes', 4),
#  ('lacra', 4),
#  ('sigues', 4),
#  ('podes', 4),
#  ('JODER', 4),
#  ('CAGO', 4),
#  ('resentido', 4),
#  ('tanga', 4),
#  ('dejas', 4),
#  ('acaban', 4),
#  ('acabo', 4),
#  ('Vete', 4),
#  ('verte', 4),
#  ('cielo', 4),
#  ('darte', 4),
#  ('andan', 4),
#  ('llamando', 4),
#  ('gata', 4),
#  ('universidad', 4),
#  ('quitan', 4),
#  ('vídeos', 4),
#  ('xddd', 4),
#  ('acosos', 4),
#  ('coqueteo', 4),
#  ('insistente', 4),
#  ('ICE', 4),
#  ('seguridad', 4),
#  ('feminista', 4),
#  ('hablo', 4),
#  ('discursos', 4),
#  ('JAJAJA', 4),
#  ('violador', 4),
#  ('industria', 4),
#  ('pensando', 4),
#  ('inglés', 4),
#  ('aprender', 4),
#  ('pollas', 4),
#  ('hola', 4),
#  ('mitad', 4),
#  ('enserio', 4),
#  ('música', 4),
#  ('bastardo', 4),
#  ('decreto', 4),
#  ('Video', 4),
#  ('Perú', 4),
#  ('recibir', 4),
#  ('jóvenes', 4),
#  ('@A3Noticias', 4),
#  ('director', 4),
#  ('nalgas', 4),
#  ('pelotas', 4),
#  ('defiende', 4),
#  ('adolescentes', 4),
#  ('cifras', 4),
#  ('mata', 4),
#  ('@VicenteFoxQue', 4),
#  ('cagada', 4),
#  ('dejan', 4),
#  ('sirios', 4),
#  ('fan', 4),
#  ('vayan', 4),
#  ('preso', 4),
#  ('mover', 4),
#  ('carcel', 4),
#  ('territorio', 4),
#  ('verguenza', 4),
#  ('pensiones', 4),
#  ('sueño', 4),
#  ('importante', 4),
#  ('bola', 4),
#  ('vienen', 4),
#  ('gustó', 4),
#  ('tiempos', 4),
#  ('@SergioMassa', 4),
#  ('político', 4),
#  ('desgracia', 4),
#  ('producto', 4),
#  ('salud', 4),
#  ('abre', 4),
#  ('UCO', 4),
#  ('VIOLACIÓN', 4),
#  ('nominación', 4),
#  ('Lamas', 4),
#  ('tio', 4),
#  ('jeta', 4),
#  ('productor', 4),
#  ('sol', 4),
#  ('Dubái', 4),
#  ('tetas', 4),
#  ('Zidane', 4),
#  ('400', 4),
#  ('MORIR', 4),
#  ('tratar', 4),
#  ('enseñarte', 4),
#  ('imagínate', 4),
#  ('izquierda', 4),
#  ('mirar', 4),
#  ('profesionales', 4),
#  ('buscan', 4),
#  ('vestirse', 4),
#  ('Jajajajaja', 4),
#  ('Puto', 4),
#  ('grita', 4),
#  ('pija', 4),
#  ('pienso', 4),
#  ('escolar', 4),
#  ('queréis', 4),
#  ('vidas', 4),
#  ('Madrid', 4),
#  ('Barcelona', 4),
#  ('Ciudadanos', 4),
#  ('tocando', 4),
#  ('amigas', 4),
#  ('caca', 4),
#  ('millón', 4),
#  ('@pablocasado', 4),
#  ('FLOR', 4),
#  ('@flor_vigna', 4),
#  ('esposa', 4),
#  ('hagas', 4),
#  ('crack', 4),
#  ('ok', 4),
#  ('leche', 4),
#  ('vecinos', 4),
#  ('chabon', 4),
#  ('Enhorabuena', 4),
#  ('perfecto', 4),
#  ('alumnos', 4),
#  ('   ', 4),
#  ('fascista', 4),
#  ('cambio', 4),
#  ('artista', 4),
#  ('@realmadrid', 4),
#  ('navidad', 4),
#  ('palos', 4),
#  ('entradas', 4),
#  ('@aurelionuno', 4),
#  ('estúpida', 4),
#  ('volver', 4),
#  ('aca', 4),
#  ('Hombre', 4),
#  ('reciben', 4),
#  ('Iglesias', 4),
#  ('españoles', 4),
#  ('centros', 4),
#  ('rescatados', 4),
#  ('pelicula', 4),
#  ('Mereces', 4),
#  ('@elmundoes', 4),
#  ('aviso', 4),
#  ('daba', 4),
#  ('dejado', 4),
#  ('prima', 4),
#  ('actuación', 4),
#  ('FORRO', 4),
#  ('alv', 4),
#  ('vuelve', 4),
#  ('vienes', 4),
#  ('@TowandaRebels', 4),
#  ('existencia', 4),
#  ('historias', 4),
#  ('digas', 4),
#  ('PEGO', 4),
#  ('@ertenembaum', 4),
#  ('sexuales', 4),
#  ('forro', 4),
#  ('manda', 4),
#  ('Tepito', 4),
#  ('sitio', 4),
#  ('Unido', 4),
#  ('numero', 4),
#  ('disfrutar', 4),
#  ('porqué', 4),
#  ('sinceramente', 4),
#  ('noches', 4),
#  ('cariño', 4),
#  ('enviar', 4),
#  ('página', 4),
#  ('grupo', 4),
#  ('social', 4),
#  ('corriendo', 4),
#  ('decirle', 4),
#  ('Español', 4),
#  ('fiel', 4),
#  ('14', 4),
#  ('Arizona', 4),
#  ('pasó', 4),
#  ('punta', 4),
#  ('felicidades', 4),
#  ('Mexico', 4),
#  ('simplemente', 4),
#  ('lengua', 4),
#  ('dolor', 4),
#  ('terminar', 4),
#  ('24', 4),
#  ('chile', 4),
#  ('pega', 4),
#  ('inteligente', 4),
#  ('porfa', 4),
#  ('tenés', 4),
#  ('15', 4),
#  ('centro', 4),
#  ('Violencia', 4),
#  ('conoces', 4),
#  ('meter', 4),
#  ('sociales', 4),
#  ('FLORENCIA', 4),
#  ('escena', 4),
#  ('PERSONA', 4),
#  ('saca', 4),
#  ('terroristas', 4),
#  ('llevo', 4),
#  ('ORTO', 4),
#  ('detención', 4),
#  ('xd', 4),
#  ('The', 4),
#  ('toca', 4),
#  ('LPM', 4),
#  ('Siria', 4),
#  ('cumple', 4),
#  ('comunidad', 4),
#  ('@Pablo_Iglesias', 4),
#  ('catalufos', 4),
#  ('vives', 4),
#  ('escribir', 4),
#  ('corrupto', 4),
#  ('oye', 4),
#  ('tacos', 4),
#  ('follarte', 4),
#  ('experiencia', 4),
#  ...]
